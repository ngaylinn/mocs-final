# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt

# %%
def plot_neutral_mutations(file):
    with open(file, 'rb') as pf:
        data = pickle.load(pf)
    
    neutral_mutations = data.n_neutral_over_generations[1:]
    neutral_mutations_proportions = np.array(neutral_mutations) / data.target_population_size
    
    plt.plot(neutral_mutations_proportions)
    plt.show()

# %%
def plot_mutation_beneficiality(file):
    with open(file, 'rb') as pf:
        data = pickle.load(pf)
    

    pairs_over_gens = data.parent_child_fitness_history[1:]
    prop_beneficial = [len([pair for pair in gen if pair[0] > pair[1]]) / len(gen) for gen in pairs_over_gens]
    prop_neutral = [len([pair for pair in gen if pair[0] == pair[1]]) / len(gen) for gen in pairs_over_gens]
    prop_deleterious = [len([pair for pair in gen if pair[0] < pair[1]]) / len(gen) for gen in pairs_over_gens]
    plt.plot(prop_beneficial, label='beneficial')
    plt.plot(prop_neutral, label='neutral')
    plt.plot(prop_deleterious, label='deleterious')
    plt.xlabel('Generations')
    plt.legend()
    plt.show()

# %%
plot_neutral_mutations('./hillclimber_test_t0.pkl')
plot_mutation_beneficiality('./hillclimber_test_t0.pkl')

# %%
from collections import Counter
def compress_array(arr, N):
    # Calculate the number of chunks
    num_chunks = len(arr) // N
    
    # Initialize the compressed array
    compressed = []
    
    # Iterate over each chunk
    for i in range(num_chunks):
        # Calculate the average of the current chunk
        avg = sum(arr[i*N:(i+1)*N]) / N
        
        # Append the average to the compressed array
        compressed.append(avg)
    
    # Handle the case where the original array size is not a multiple of N
    # by averaging the remaining elements, if any
    remainder = len(arr) % N
    if remainder != 0:
        avg_remainder = sum(arr[-remainder:]) / remainder
        compressed.append(avg_remainder)
    
    return compressed


def plot_multiscale_neutrality(file):
    with open(file, 'rb') as pf:
        hc = pickle.load(pf)

    l1_neutral = []
    l2_neutral = []
    l3_neutral = []
    l4_neutral = []
    
    for gen in range(0, len(hc.mutation_data_over_generations)-1):
        neutral = [pair[0] == pair[1] for pair in hc.parent_child_fitness_history[gen+1]]

        layers_neutral = np.array(hc.mutation_data_over_generations[gen]['layer'])[neutral]
        neutral_count = Counter(layers_neutral)
        if 0 in neutral_count:
            l1_neutral.append(neutral_count[0] / hc.target_population_size)
        if 1 in neutral_count:
            l2_neutral.append(neutral_count[1]/ hc.target_population_size)
        if 2 in neutral_count:
            l3_neutral.append(neutral_count[2]/ hc.target_population_size)
        else:
            l3_neutral.append(0)
        if 3 in neutral_count:
            l4_neutral.append(neutral_count[3]/ hc.target_population_size)
        else:
            l4_neutral.append(0)

    gen_avg = 10
    time_avg_l1 = compress_array(l1_neutral, gen_avg)
    time_avg_l2 = compress_array(l2_neutral, gen_avg)
    time_avg_l3 = compress_array(l3_neutral, gen_avg)
    time_avg_l4 = compress_array(l4_neutral, gen_avg)

    x_vals = range(0, len(hc.mutation_data_over_generations)-1, gen_avg)

    plt.plot(x_vals, time_avg_l4, label='Layer 4 (top)')
    plt.plot(x_vals, time_avg_l3, label='Layer 3')
    plt.plot(x_vals, time_avg_l2, label='Layer 2')
    plt.plot(x_vals, time_avg_l1, label='Layer 1 (bottom)')
    plt.legend()

    plt.xlabel('Generation')
    plt.ylabel('Neutral mutations as a proportion of all mutations')
    plt.title('Neutral mutations as a proportion of all mutations at each layer')
        

plot_multiscale_neutrality('./hillclimber_test_t0.pkl')

# %%
def plot_normalized_multiscale_neutrality(file):
    with open(file, 'rb') as pf:
        hc = pickle.load(pf)

    l1_neutral = []
    l2_neutral = []
    l3_neutral = []
    l4_neutral = []
    
    for gen in range(0, len(hc.mutation_data_over_generations)-1):
        hc.mutation_data_over_generations[gen]['layer']
        hc.parent_child_distance_history[gen+1]

        neutral = [pair[0] == pair[1] for pair in hc.parent_child_fitness_history[gen+1]]
        n_neutral = sum(neutral)

        layers_neutral = np.array(hc.mutation_data_over_generations[gen]['layer'])[neutral]
        neutral_count = Counter(layers_neutral)
        if 0 in neutral_count:
            l1_neutral.append(neutral_count[0] / n_neutral)
        if 1 in neutral_count:
            l2_neutral.append(neutral_count[1] / n_neutral)
        if 2 in neutral_count:
            l3_neutral.append(neutral_count[2] / n_neutral)
        else:
            l3_neutral.append(0)
        if 3 in neutral_count:
            l4_neutral.append(neutral_count[3] / n_neutral)
        else:
            l4_neutral.append(0)

    gen_avg = 10
    time_avg_l1 = compress_array(l1_neutral, gen_avg)
    time_avg_l2 = compress_array(l2_neutral, gen_avg)
    time_avg_l3 = compress_array(l3_neutral, gen_avg)
    time_avg_l4 = compress_array(l4_neutral, gen_avg)

    x_vals = range(0, len(hc.mutation_data_over_generations)-1, gen_avg)

    plt.plot(x_vals, time_avg_l4, label='Layer 4 (top)')
    plt.plot(x_vals, time_avg_l3, label='Layer 3')
    plt.plot(x_vals, time_avg_l2, label='Layer 2')
    plt.plot(x_vals, time_avg_l1, label='Layer 1 (bottom)')

    plt.xlabel('Generation')
    plt.ylabel('Neutrality')
    plt.title('Proportion of neutral mutations for each layer')

    plt.legend(loc='upper left')
        

# plot_normalized_multiscale_neutrality('./hillclimber_test_t0.pkl')
plot_normalized_multiscale_neutrality('./hc_testeroni_5000_wo.pkl')

# %%
from collections import Counter

def plot_multiscale_neutrality(file):
    with open(file, 'rb') as pf:
        hc = pickle.load(pf)

    parent_pop_keys = list(hc.parent_population.keys())
    sol = hc.parent_population[parent_pop_keys[0]]
    print(Counter(hc.mutation_data_over_generations[1]['kind']))
    print(sol.get_layer_state_indices(0))
    print(sol.get_layer_state_indices(1))
    print(sol.get_layer_state_indices(2))
    print(sol.get_layer_state_indices(3))

    print(sol.state_genotype)
    

plot_multiscale_neutrality('./hillclimber_test_t0.pkl')

# %%
def plot_multiscale_neutrality_mutation_kind(file):
    with open(file, 'rb') as pf:
        hc = pickle.load(pf)

    above_neutral = []
    around_neutral = []
    below_neutral = []
    
    for gen in range(0, len(hc.mutation_data_over_generations)-1):
        neutral = [pair[0] == pair[1] for pair in hc.parent_child_fitness_history[gen+1]]

        kind_neutral = np.array(hc.mutation_data_over_generations[gen]['kind'])[neutral]

        neutral_count = Counter(kind_neutral)
        if 'above' in neutral_count:
            above_neutral.append(neutral_count['above'] / hc.target_population_size)
        else:
            above_neutral.append(0)

        if 'below' in neutral_count:
            below_neutral.append(neutral_count['below']/ hc.target_population_size)
        else:
            below_neutral.append(0)

        if 'around' in neutral_count:
            around_neutral.append(neutral_count['around']/ hc.target_population_size)
        else:
            around_neutral.append(0)

    gen_avg = 10
    time_avg_above = compress_array(above_neutral, gen_avg)
    time_avg_around = compress_array(around_neutral, gen_avg)
    time_avg_below = compress_array(below_neutral, gen_avg)

    x_vals = range(0, len(hc.mutation_data_over_generations)-1, gen_avg)

    plt.plot(x_vals, time_avg_above, label='Above neutral')
    plt.plot(x_vals, time_avg_around, label='Around neutral')
    plt.plot(x_vals, time_avg_below, label='Below neutral')

    plt.legend()

    plt.xlabel('Generation')
    plt.ylabel('Neutral mutations as a proportion of all mutations')
    plt.title('Neutral mutations as a proportion of all mutations at each layer')
        

plot_multiscale_neutrality_mutation_kind('./hillclimber_test_t0.pkl')

# %%
def plot_multiscale_neutrality_mutation_kind_normalized(file):
    with open(file, 'rb') as pf:
        hc = pickle.load(pf)

    above_neutral = []
    around_neutral = []
    below_neutral = []

    all_above = []
    all_around = []
    all_below = []
    
    for gen in range(0, len(hc.mutation_data_over_generations)-1):
        neutral = [pair[0] == pair[1] for pair in hc.parent_child_fitness_history[gen+1]]
        n_neutral = sum(neutral)

        kinds = Counter(hc.mutation_data_over_generations[gen]['kind'])
        print(kinds)
        if 'above' in kinds:
            all_above.append(kinds['above'] / hc.target_population_size)
        else:
            all_above.append(0)
        if 'around' in kinds:
            all_around.append(kinds['around'] / hc.target_population_size)
        else:
            all_around.append(0)
        if 'below' in kinds:
            all_below.append(kinds['below'] / hc.target_population_size)
        else:
            all_below.append(0)

        kind_neutral = np.array(hc.mutation_data_over_generations[gen]['kind'])[neutral]

        neutral_count = Counter(kind_neutral)
        if 'above' in neutral_count:
            above_neutral.append(neutral_count['above'] / n_neutral)
        else:
            above_neutral.append(0)

        if 'below' in neutral_count:
            below_neutral.append(neutral_count['below']/ n_neutral)
        else:
            below_neutral.append(0)

        if 'around' in neutral_count:
            around_neutral.append(neutral_count['around']/ n_neutral)
        else:
            around_neutral.append(0)

    gen_avg = 10
    time_avg_above = compress_array(above_neutral, gen_avg)
    time_avg_around = compress_array(around_neutral, gen_avg)
    time_avg_below = compress_array(below_neutral, gen_avg)

    time_avg_all_above = compress_array(all_above, gen_avg)
    time_avg_all_around = compress_array(all_around, gen_avg)
    time_avg_all_below = compress_array(all_below, gen_avg)

    x_vals = range(0, len(hc.mutation_data_over_generations)-1, gen_avg)

    plt.plot(x_vals, time_avg_above, label='Above neutral')
    plt.plot(x_vals, time_avg_around, label='Around neutral')
    plt.plot(x_vals, time_avg_below, label='Below neutral')

    plt.plot(x_vals, time_avg_all_above, label='Above neutral (all)')
    plt.plot(x_vals, time_avg_all_around, label='Around neutral (all)')
    plt.plot(x_vals, time_avg_all_below, label='Below neutral (all)')

    plt.legend()

    plt.xlabel('Generation')
    plt.ylabel('Neutral mutations as a proportion of all mutations')
    plt.title('Neutral mutations as a proportion of all mutations at each layer')
        

plot_multiscale_neutrality_mutation_kind_normalized('./hillclimber_test_t0.pkl')
# Out:
# Counter({'around': 309, 'below': 130, None: 41, 'above': 21})
# Counter({'around': 307, 'below': 122, None: 41, 'above': 31})
# Counter({'around': 311, 'below': 134, None: 33, 'above': 23})
# Counter({'around': 303, 'below': 131, None: 36, 'above': 31})
# Counter({'around': 299, 'below': 131, None: 42, 'above': 29})
# Counter({'around': 305, 'below': 127, None: 46, 'above': 23})
# Counter({'around': 294, 'below': 130, None: 49, 'above': 28})
# Counter({'around': 306, 'below': 133, 'above': 32, None: 30})
# Counter({'around': 313, 'below': 113, None: 42, 'above': 33})
# Counter({'around': 336, 'below': 102, None: 35, 'above': 28})
# Counter({'around': 311, 'below': 117, None: 50, 'above': 23})
# Counter({'around': 308, 'below': 121, None: 43, 'above': 29})
# Counter({'around': 324, 'below': 106, None: 48, 'above': 23})
# Counter({'around': 328, 'below': 104, None: 38, 'above': 31})
# Counter({'around': 296, 'below': 143, None: 40, 'above': 22})
# Counter({'around': 322, 'below': 112, None: 35, 'above': 32})
# Counter({'around': 332, 'below': 106, None: 42, 'above': 21})
# Counter({'around': 303, 'below': 130, None: 41, 'above': 27})
# Counter({'around': 326, 'below': 109, None: 37, 'above': 29})
# Counter({'around': 304, 'below': 123, None: 43, 'above': 31})
# Counter({'around': 318, 'below': 95, None: 51, 'above': 37})
# Counter({'around': 309, 'below': 125, 'above': 34, None: 33})
# Counter({'around': 328, 'below': 97, None: 39, 'above': 37})
# Counter({'around': 329, 'below': 113, None: 33, 'above': 26})
# Counter({'around': 295, 'below': 131, None: 38, 'above': 37})
# Counter({'around': 313, 'below': 117, 'above': 37, None: 34})
# Counter({'around': 331, 'below': 111, 'above': 31, None: 28})
# Counter({'around': 323, 'below': 113, None: 40, 'above': 25})
# Counter({'around': 326, 'below': 117, None: 40, 'above': 18})
# Counter({'around': 329, 'below': 111, None: 33, 'above': 28})
# Counter({'around': 306, 'below': 127, None: 47, 'above': 21})
# Counter({'around': 312, 'below': 129, None: 35, 'above': 25})
# Counter({'around': 321, 'below': 105, None: 39, 'above': 36})
# Counter({'around': 316, 'below': 129, None: 29, 'above': 27})
# Counter({'around': 317, 'below': 108, None: 41, 'above': 35})
# Counter({'around': 311, 'below': 122, None: 41, 'above': 27})
# Counter({'around': 323, 'below': 120, None: 33, 'above': 25})
# Counter({'around': 315, 'below': 109, None: 45, 'above': 32})
# Counter({'around': 318, 'below': 118, None: 34, 'above': 31})
# Counter({'around': 289, 'below': 133, 'above': 41, None: 38})
# Counter({'around': 332, 'below': 110, None: 39, 'above': 20})
# Counter({'around': 325, 'below': 112, None: 41, 'above': 23})
# Counter({'around': 304, 'below': 129, None: 36, 'above': 32})
# Counter({'around': 332, 'below': 113, 'above': 28, None: 28})
# Counter({'around': 316, 'below': 115, 'above': 38, None: 32})
# Counter({'around': 315, 'below': 123, None: 37, 'above': 26})
# Counter({'around': 325, 'below': 99, None: 46, 'above': 31})
# Counter({'around': 328, 'below': 110, 'above': 33, None: 30})
# Counter({'around': 307, 'below': 125, None: 43, 'above': 26})
# Counter({'around': 320, 'below': 110, None: 42, 'above': 29})
# Counter({'around': 320, 'below': 103, 'above': 40, None: 38})
# Counter({'around': 328, 'below': 117, None: 34, 'above': 22})
# Counter({'around': 324, 'below': 93, None: 51, 'above': 33})
# Counter({'around': 328, 'below': 109, 'above': 35, None: 29})
# Counter({'around': 316, 'below': 130, None: 33, 'above': 22})
# Counter({'around': 324, 'below': 111, 'above': 36, None: 30})
# Counter({'around': 308, 'below': 112, None: 46, 'above': 35})
# Counter({'around': 308, 'below': 121, None: 42, 'above': 30})
# Counter({'around': 298, 'below': 135, None: 35, 'above': 33})
# Counter({'around': 312, 'below': 124, None: 46, 'above': 19})
# Counter({'around': 323, 'below': 111, None: 37, 'above': 30})
# Counter({'around': 309, 'below': 122, None: 37, 'above': 33})
# Counter({'around': 294, 'below': 141, None: 43, 'above': 23})
# Counter({'around': 330, 'below': 110, None: 41, 'above': 20})
# Counter({'around': 315, 'below': 103, None: 42, 'above': 41})
# Counter({'around': 332, 'below': 104, None: 45, 'above': 20})
# Counter({'around': 321, 'below': 118, None: 35, 'above': 27})
# Counter({'around': 312, 'below': 117, None: 46, 'above': 26})
# Counter({'around': 303, 'below': 113, None: 43, 'above': 42})
# Counter({'around': 318, 'below': 125, None: 36, 'above': 22})
# Counter({'around': 337, 'below': 99, None: 38, 'above': 27})
# Counter({'around': 324, 'below': 111, None: 40, 'above': 26})
# Counter({'around': 305, 'below': 127, None: 37, 'above': 32})
# Counter({'around': 317, 'below': 113, None: 46, 'above': 25})
# Counter({'around': 328, 'below': 109, None: 37, 'above': 27})
# Counter({'around': 323, 'below': 118, 'above': 32, None: 28})
# Counter({'around': 319, 'below': 114, None: 40, 'above': 28})
# Counter({'around': 328, 'below': 116, None: 34, 'above': 23})
# Counter({'around': 323, 'below': 112, None: 37, 'above': 29})
# Counter({'around': 300, 'below': 124, 'above': 40, None: 37})
# Counter({'around': 309, 'below': 123, None: 37, 'above': 32})
# Counter({'around': 319, 'below': 106, None: 47, 'above': 29})
# Counter({'around': 317, 'below': 113, 'above': 37, None: 34})
# Counter({'around': 321, 'below': 118, None: 34, 'above': 28})
# Counter({'around': 327, 'below': 101, None: 42, 'above': 31})
# Counter({'around': 310, 'below': 129, None: 35, 'above': 27})
# Counter({'around': 308, 'below': 120, None: 45, 'above': 28})
# Counter({'around': 326, 'below': 97, None: 51, 'above': 27})
# Counter({'around': 311, 'below': 126, None: 36, 'above': 28})
# Counter({'around': 311, 'below': 114, None: 45, 'above': 31})
# Counter({'around': 316, 'below': 116, None: 38, 'above': 31})
# Counter({'around': 301, 'below': 130, None: 38, 'above': 32})
# Counter({'around': 326, 'below': 110, None: 34, 'above': 31})
# Counter({'around': 330, 'below': 118, None: 29, 'above': 24})
# Counter({'around': 315, 'below': 120, None: 34, 'above': 32})
# Counter({'around': 333, 'below': 113, 'above': 30, None: 25})
# Counter({'around': 332, 'below': 110, None: 38, 'above': 21})
# Counter({'around': 286, 'below': 144, None: 38, 'above': 33})
# Counter({'around': 307, 'below': 117, None: 49, 'above': 28})
# Counter({'around': 325, 'below': 118, None: 33, 'above': 25})
# Counter({'around': 300, 'below': 129, None: 45, 'above': 27})
# Counter({'around': 318, 'below': 108, None: 43, 'above': 32})
# Counter({'around': 321, 'below': 105, None: 52, 'above': 23})
# Counter({'around': 326, 'below': 105, None: 43, 'above': 27})
# Counter({'around': 314, 'below': 122, None: 34, 'above': 31})
# Counter({'around': 312, 'below': 118, 'above': 37, None: 34})
# Counter({'around': 321, 'below': 118, None: 40, 'above': 22})
# Counter({'around': 331, 'below': 103, None: 43, 'above': 24})
# Counter({'around': 319, 'below': 116, None: 38, 'above': 28})
# Counter({'around': 313, 'below': 125, None: 33, 'above': 30})
# Counter({'around': 307, 'below': 129, None: 34, 'above': 31})
# Counter({'around': 317, 'below': 116, None: 48, 'above': 20})
# Counter({'around': 305, 'below': 129, 'above': 34, None: 33})
# Counter({'around': 305, 'below': 121, None: 41, 'above': 34})
# Counter({'around': 313, 'below': 112, None: 48, 'above': 28})
# Counter({'around': 307, 'below': 123, None: 38, 'above': 33})
# Counter({'around': 338, 'below': 113, None: 27, 'above': 23})
# Counter({'around': 312, 'below': 111, None: 47, 'above': 31})
# Counter({'around': 318, 'below': 123, None: 42, 'above': 18})
# Counter({'around': 312, 'below': 115, None: 44, 'above': 30})
# Counter({'around': 326, 'below': 115, None: 39, 'above': 21})
# Counter({'around': 307, 'below': 122, None: 45, 'above': 27})
# Counter({'around': 309, 'below': 131, None: 40, 'above': 21})
# Counter({'around': 311, 'below': 116, None: 45, 'above': 29})
# Counter({'around': 315, 'below': 108, None: 43, 'above': 35})
# Counter({'around': 325, 'below': 110, None: 41, 'above': 25})
# Counter({'around': 340, 'below': 105, None: 31, 'above': 25})
# Counter({'around': 315, 'below': 116, None: 46, 'above': 24})
# Counter({'around': 311, 'below': 128, None: 42, 'above': 20})
# Counter({'around': 311, 'below': 114, None: 46, 'above': 30})
# Counter({'around': 326, 'below': 111, None: 39, 'above': 25})
# Counter({'around': 308, 'below': 129, None: 38, 'above': 26})
# Counter({'around': 308, 'below': 134, None: 36, 'above': 23})
# Counter({'around': 316, 'below': 114, None: 40, 'above': 31})
# Counter({'around': 318, 'below': 108, None: 43, 'above': 32})
# Counter({'around': 303, 'below': 133, None: 38, 'above': 27})
# Counter({'around': 307, 'below': 123, None: 38, 'above': 33})
# Counter({'around': 315, 'below': 132, None: 29, 'above': 25})
# Counter({'around': 314, 'below': 114, None: 40, 'above': 33})
# Counter({'around': 300, 'below': 126, None: 54, 'above': 21})
# Counter({'around': 305, 'below': 120, None: 48, 'above': 28})
# Counter({'around': 297, 'below': 128, None: 39, 'above': 37})
# Counter({'around': 302, 'below': 138, None: 33, 'above': 28})
# Counter({'around': 329, 'below': 92, None: 46, 'above': 34})
# Counter({'around': 308, 'below': 121, None: 46, 'above': 26})
# Counter({'around': 298, 'below': 124, None: 43, 'above': 36})
# Counter({'around': 306, 'below': 118, None: 47, 'above': 30})
# Counter({'around': 322, 'below': 119, None: 33, 'above': 27})
# Counter({'around': 316, 'below': 129, None: 28, 'above': 28})
# Counter({'around': 312, 'below': 132, None: 34, 'above': 23})
# Counter({'around': 304, 'below': 127, None: 42, 'above': 28})
# Counter({'around': 317, 'below': 116, 'above': 37, None: 31})
# Counter({'around': 322, 'below': 116, None: 39, 'above': 24})
# Counter({'around': 298, 'below': 125, 'above': 41, None: 37})
# Counter({'around': 295, 'below': 129, 'above': 39, None: 38})
# Counter({'around': 306, 'below': 126, None: 38, 'above': 31})
# Counter({'around': 333, 'below': 106, None: 40, 'above': 22})
# Counter({'around': 329, 'below': 103, None: 38, 'above': 31})
# Counter({'around': 309, 'below': 118, None: 43, 'above': 31})
# Counter({'around': 319, 'below': 126, None: 33, 'above': 23})
# Counter({'around': 309, 'below': 118, None: 42, 'above': 32})
# Counter({'around': 325, 'below': 110, None: 39, 'above': 27})
# Counter({'around': 321, 'below': 106, None: 37, 'above': 37})
# Counter({'around': 329, 'below': 98, None: 45, 'above': 29})
# Counter({'around': 325, 'below': 113, None: 44, 'above': 19})
# Counter({'around': 319, 'below': 109, 'above': 44, None: 29})
# Counter({'around': 319, 'below': 107, None: 45, 'above': 30})
# Counter({'around': 334, 'below': 108, None: 32, 'above': 27})
# Counter({'around': 305, 'below': 119, None: 41, 'above': 36})
# Counter({'around': 315, 'below': 117, None: 44, 'above': 25})
# Counter({'around': 320, 'below': 115, None: 37, 'above': 29})
# Counter({'around': 307, 'below': 119, None: 42, 'above': 33})
# Counter({'around': 326, 'below': 111, None: 34, 'above': 30})
# Counter({'around': 326, 'below': 101, None: 43, 'above': 31})
# Counter({'around': 321, 'below': 121, None: 37, 'above': 22})
# Counter({'around': 301, 'below': 127, None: 40, 'above': 33})
# Counter({'around': 337, 'below': 96, 'above': 38, None: 30})
# Counter({'around': 310, 'below': 122, None: 42, 'above': 27})
# Counter({'around': 313, 'below': 114, None: 43, 'above': 31})
# Counter({'around': 316, 'below': 113, None: 46, 'above': 26})
# Counter({'around': 318, 'below': 113, None: 36, 'above': 34})
# Counter({'around': 312, 'below': 119, None: 43, 'above': 27})
# Counter({'around': 305, 'below': 124, None: 37, 'above': 35})
# Counter({'around': 314, 'below': 123, None: 40, 'above': 24})
# Counter({'around': 338, 'below': 107, None: 31, 'above': 25})
# Counter({'around': 315, 'below': 118, None: 34, 'above': 34})
# Counter({'around': 297, 'below': 131, None: 40, 'above': 33})
# Counter({'around': 310, 'below': 120, None: 43, 'above': 28})
# Counter({'around': 316, 'below': 117, None: 37, 'above': 31})
# Counter({'around': 306, 'below': 119, None: 42, 'above': 34})
# Counter({'around': 316, 'below': 115, 'above': 37, None: 33})
# Counter({'around': 312, 'below': 120, None: 38, 'above': 31})
# Counter({'around': 305, 'below': 135, None: 33, 'above': 28})
# Counter({'around': 314, 'below': 114, None: 45, 'above': 28})
# Counter({'around': 310, 'below': 116, None: 42, 'above': 33})
# Counter({'around': 315, 'below': 118, None: 39, 'above': 29})
# Counter({'around': 335, 'below': 96, 'above': 38, None: 32})
# Counter({'around': 315, 'below': 116, None: 44, 'above': 26})
# Counter({'around': 326, 'below': 108, None: 37, 'above': 30})
# Counter({'around': 314, 'below': 118, None: 36, 'above': 33})
# Counter({'around': 312, 'below': 114, None: 46, 'above': 29})
# Counter({'around': 327, 'below': 109, None: 41, 'above': 24})
# Counter({'around': 321, 'below': 109, None: 45, 'above': 26})
# Counter({'around': 321, 'below': 109, None: 39, 'above': 32})
# Counter({'around': 315, 'below': 115, None: 39, 'above': 32})
# Counter({'around': 316, 'below': 107, 'above': 43, None: 35})
# Counter({'around': 305, 'below': 134, None: 34, 'above': 28})
# Counter({'around': 306, 'below': 136, 'above': 34, None: 25})
# Counter({'around': 318, 'below': 108, 'above': 43, None: 32})
# Counter({'around': 332, 'below': 108, None: 36, 'above': 25})
# Counter({'around': 305, 'below': 126, 'above': 38, None: 32})
# Counter({'around': 326, 'below': 112, None: 34, 'above': 29})
# Counter({'around': 304, 'below': 127, None: 42, 'above': 28})
# Counter({'around': 315, 'below': 114, None: 50, 'above': 22})
# Counter({'around': 328, 'below': 110, None: 41, 'above': 22})
# Counter({'around': 321, 'below': 124, None: 33, 'above': 23})
# Counter({'around': 298, 'below': 111, None: 46, 'above': 46})
# Counter({'around': 322, 'below': 104, None: 42, 'above': 33})
# Counter({'around': 313, 'below': 125, None: 32, 'above': 31})
# Counter({'around': 308, 'below': 118, None: 44, 'above': 31})
# Counter({'around': 322, 'below': 111, None: 36, 'above': 32})
# Counter({'around': 337, 'below': 114, None: 32, 'above': 18})
# Counter({'around': 309, 'below': 123, None: 40, 'above': 29})
# Counter({'around': 327, 'below': 113, None: 38, 'above': 23})
# Counter({'around': 316, 'below': 116, None: 35, 'above': 34})
# Counter({'around': 335, 'below': 95, None: 47, 'above': 24})
# Counter({'around': 299, 'below': 133, 'above': 35, None: 34})
# Counter({'around': 306, 'below': 126, 'above': 38, None: 31})
# Counter({'around': 312, 'below': 120, None: 42, 'above': 27})
# Counter({'around': 313, 'below': 108, None: 45, 'above': 35})
# Counter({'around': 332, 'below': 98, None: 38, 'above': 33})
# Counter({'around': 324, 'below': 114, 'above': 33, None: 30})
# Counter({'around': 324, 'below': 119, None: 37, 'above': 21})
# Counter({'around': 329, 'below': 120, 'above': 31, None: 21})
# Counter({'around': 309, 'below': 99, None: 55, 'above': 38})
# Counter({'around': 303, 'below': 125, None: 45, 'above': 28})
# Counter({'around': 336, 'below': 99, None: 40, 'above': 26})
# Counter({'around': 298, 'below': 131, None: 44, 'above': 28})
# Counter({'around': 307, 'below': 138, None: 29, 'above': 27})
# Counter({'around': 310, 'below': 119, 'above': 39, None: 33})
# Counter({'around': 330, 'below': 109, 'above': 34, None: 28})
# Counter({'around': 317, 'below': 109, None: 39, 'above': 36})
# Counter({'around': 312, 'below': 115, None: 40, 'above': 34})
# Counter({'around': 310, 'below': 124, None: 49, 'above': 18})
# Counter({'around': 317, 'below': 105, None: 54, 'above': 25})
# Counter({'around': 300, 'below': 141, None: 40, 'above': 20})
# Counter({'around': 310, 'below': 119, None: 40, 'above': 32})
# Counter({'around': 317, 'below': 124, None: 39, 'above': 21})
# Counter({'around': 317, 'below': 117, 'above': 35, None: 32})
# Counter({'around': 324, 'below': 103, None: 41, 'above': 33})
# Counter({'around': 310, 'below': 115, None: 41, 'above': 35})
# Counter({'around': 338, 'below': 111, None: 33, 'above': 19})
# Counter({'around': 313, 'below': 116, None: 38, 'above': 34})
# Counter({'around': 313, 'below': 124, None: 34, 'above': 30})
# Counter({'around': 320, 'below': 118, 'above': 33, None: 30})
# Counter({'around': 299, 'below': 111, None: 56, 'above': 35})
# Counter({'around': 321, 'below': 119, None: 33, 'above': 28})
# Counter({'around': 320, 'below': 119, None: 37, 'above': 25})
# Counter({'around': 290, 'below': 135, None: 41, 'above': 35})
# Counter({'around': 332, 'below': 110, None: 39, 'above': 20})
# Counter({'around': 326, 'below': 109, None: 47, 'above': 19})
# Counter({'around': 318, 'below': 114, None: 43, 'above': 26})
# Counter({'around': 318, 'below': 114, None: 40, 'above': 29})
# Counter({'around': 295, 'below': 126, None: 43, 'above': 37})
# Counter({'around': 315, 'below': 107, None: 47, 'above': 32})
# Counter({'around': 305, 'below': 137, None: 30, 'above': 29})
# Counter({'around': 304, 'below': 121, 'above': 39, None: 37})
# Counter({'around': 302, 'below': 125, None: 40, 'above': 34})
# Counter({'around': 298, 'below': 139, None: 40, 'above': 24})
# Counter({'around': 326, 'below': 103, None: 45, 'above': 27})
# Counter({'around': 303, 'below': 132, 'above': 35, None: 31})
# Counter({'around': 312, 'below': 126, None: 38, 'above': 25})
# Counter({'around': 304, 'below': 138, None: 36, 'above': 23})
# Counter({'around': 313, 'below': 114, 'above': 38, None: 36})
# Counter({'around': 319, 'below': 115, 'above': 35, None: 32})
# Counter({'around': 310, 'below': 114, None: 46, 'above': 31})
# Counter({'around': 318, 'below': 117, None: 40, 'above': 26})
# Counter({'around': 332, 'below': 104, None: 36, 'above': 29})
# Counter({'around': 299, 'below': 125, None: 41, 'above': 36})
# Counter({'around': 315, 'below': 120, 'above': 34, None: 32})
# Counter({'around': 324, 'below': 111, 'above': 36, None: 30})
# Counter({'around': 307, 'below': 112, None: 43, 'above': 39})
# Counter({'around': 318, 'below': 114, None: 44, 'above': 25})
# Counter({'around': 305, 'below': 113, None: 44, 'above': 39})
# Counter({'around': 308, 'below': 131, None: 32, 'above': 30})
# Counter({'around': 318, 'below': 115, None: 40, 'above': 28})
# Counter({'around': 337, 'below': 95, None: 43, 'above': 26})
# Counter({'around': 330, 'below': 115, None: 31, 'above': 25})
# Counter({'around': 304, 'below': 113, None: 52, 'above': 32})
# Counter({'around': 293, 'below': 136, None: 48, 'above': 24})
# Counter({'around': 326, 'below': 110, 'above': 33, None: 32})
# Counter({'around': 329, 'below': 115, None: 33, 'above': 24})
# Counter({'around': 306, 'below': 124, None: 45, 'above': 26})
# Counter({'around': 300, 'below': 126, None: 42, 'above': 33})
# Counter({'around': 327, 'below': 113, None: 36, 'above': 25})
# Counter({'around': 316, 'below': 132, 'above': 28, None: 25})
# Counter({'around': 302, 'below': 125, None: 50, 'above': 24})
# Counter({'around': 314, 'below': 130, None: 29, 'above': 28})
# Counter({'around': 283, 'below': 150, None: 38, 'above': 30})
# Counter({'around': 320, 'below': 117, None: 35, 'above': 29})
# Counter({'around': 303, 'below': 122, 'above': 38, None: 38})
# Counter({'around': 305, 'below': 131, None: 39, 'above': 26})
# Counter({'around': 306, 'below': 132, None: 38, 'above': 25})
# Counter({'around': 327, 'below': 121, None: 33, 'above': 20})
# Counter({'around': 319, 'below': 108, None: 43, 'above': 31})
# Counter({'around': 316, 'below': 103, None: 51, 'above': 31})
# Counter({'around': 317, 'below': 108, None: 44, 'above': 32})
# Counter({'around': 316, 'below': 115, None: 43, 'above': 27})
# Counter({'around': 296, 'below': 119, None: 48, 'above': 38})
# Counter({'around': 302, 'below': 117, None: 45, 'above': 37})
# Counter({'around': 312, 'below': 120, None: 41, 'above': 28})
# Counter({'around': 310, 'below': 125, 'above': 35, None: 31})
# Counter({'around': 315, 'below': 121, None: 47, 'above': 18})
# Counter({'around': 320, 'below': 117, None: 36, 'above': 28})
# Counter({'around': 319, 'below': 124, None: 34, 'above': 24})
# Counter({'around': 325, 'below': 96, None: 44, 'above': 36})
# Counter({'around': 310, 'below': 130, None: 32, 'above': 29})
# Counter({'around': 316, 'below': 112, None: 47, 'above': 26})
# Counter({'around': 313, 'below': 126, 'above': 32, None: 30})
# Counter({'around': 308, 'below': 120, None: 42, 'above': 31})
# Counter({'around': 321, 'below': 119, 'above': 31, None: 30})
# Counter({'around': 331, 'below': 105, 'above': 38, None: 27})
# Counter({'around': 306, 'below': 119, None: 43, 'above': 33})
# Counter({'around': 304, 'below': 132, None: 38, 'above': 27})
# Counter({'around': 320, 'below': 112, None: 41, 'above': 28})
# Counter({'around': 327, 'below': 117, None: 32, 'above': 25})
# Counter({'around': 325, 'below': 99, None: 50, 'above': 27})
# Counter({'around': 326, 'below': 105, None: 37, 'above': 33})
# Counter({'around': 325, 'below': 111, None: 34, 'above': 31})
# Counter({'around': 330, 'below': 122, None: 27, 'above': 22})
# Counter({'around': 310, 'below': 129, None: 40, 'above': 22})
# Counter({'around': 320, 'below': 122, None: 38, 'above': 21})
# Counter({'around': 331, 'below': 110, None: 38, 'above': 22})
# Counter({'around': 334, 'below': 116, None: 29, 'above': 22})
# Counter({'around': 315, 'below': 125, None: 33, 'above': 28})
# Counter({'around': 318, 'below': 116, None: 34, 'above': 33})
# Counter({'around': 316, 'below': 112, None: 39, 'above': 34})
# Counter({'around': 290, 'below': 132, None: 47, 'above': 32})
# Counter({'around': 321, 'below': 117, None: 39, 'above': 24})
# Counter({'around': 330, 'below': 113, None: 34, 'above': 24})
# Counter({'around': 316, 'below': 114, None: 44, 'above': 27})
# Counter({'around': 314, 'below': 115, None: 41, 'above': 31})
# Counter({'around': 330, 'below': 103, 'above': 39, None: 29})
# Counter({'around': 319, 'below': 112, None: 41, 'above': 29})
# Counter({'around': 313, 'below': 117, None: 45, 'above': 26})
# Counter({'around': 306, 'below': 119, None: 44, 'above': 32})
# Counter({'around': 334, 'below': 114, None: 31, 'above': 22})
# Counter({'around': 316, 'below': 113, None: 41, 'above': 31})
# Counter({'around': 302, 'below': 129, None: 36, 'above': 34})
# Counter({'around': 317, 'below': 107, None: 53, 'above': 24})
# Counter({'around': 336, 'below': 96, None: 37, 'above': 32})
# Counter({'around': 314, 'below': 122, None: 36, 'above': 29})
# Counter({'around': 317, 'below': 116, None: 40, 'above': 28})
# Counter({'around': 306, 'below': 116, None: 47, 'above': 32})
# Counter({'around': 322, 'below': 117, 'above': 37, None: 25})
# Counter({'around': 333, 'below': 111, None: 31, 'above': 26})
# Counter({'around': 313, 'below': 123, None: 41, 'above': 24})
# Counter({'around': 324, 'below': 119, None: 36, 'above': 22})
# Counter({'around': 322, 'below': 103, None: 41, 'above': 35})
# Counter({'around': 304, 'below': 113, None: 44, 'above': 40})
# Counter({'around': 323, 'below': 111, None: 41, 'above': 26})
# Counter({'around': 309, 'below': 120, None: 47, 'above': 25})
# Counter({'around': 321, 'below': 114, None: 39, 'above': 27})
# Counter({'around': 306, 'below': 128, None: 36, 'above': 31})
# Counter({'around': 326, 'below': 118, 'above': 29, None: 28})
# Counter({'around': 315, 'below': 109, 'above': 39, None: 38})
# Counter({'around': 337, 'below': 110, None: 31, 'above': 23})
# Counter({'around': 307, 'below': 125, 'above': 35, None: 34})
# Counter({'around': 324, 'below': 116, None: 34, 'above': 27})
# Counter({'around': 307, 'below': 132, None: 36, 'above': 26})
# Counter({'around': 318, 'below': 106, 'above': 39, None: 38})
# Counter({'around': 320, 'below': 123, None: 36, 'above': 22})
# Counter({'around': 325, 'below': 120, None: 34, 'above': 22})
# Counter({'around': 308, 'below': 111, None: 48, 'above': 34})
# Counter({'around': 311, 'below': 123, None: 39, 'above': 28})
# Counter({'around': 302, 'below': 129, None: 44, 'above': 26})
# Counter({'around': 316, 'below': 111, None: 37, 'above': 37})
# Counter({'around': 313, 'below': 112, 'above': 38, None: 38})
# Counter({'around': 321, 'below': 113, None: 41, 'above': 26})
# Counter({'around': 308, 'below': 129, None: 37, 'above': 27})
# Counter({'around': 311, 'below': 124, 'above': 41, None: 25})
# Counter({'around': 304, 'below': 128, None: 44, 'above': 25})
# Counter({'around': 331, 'below': 103, None: 41, 'above': 26})
# Counter({'around': 303, 'below': 126, None: 41, 'above': 31})
# Counter({'around': 301, 'below': 125, None: 41, 'above': 34})
# Counter({'around': 303, 'below': 126, None: 42, 'above': 30})
# Counter({'around': 316, 'below': 104, None: 50, 'above': 31})
# Counter({'around': 311, 'below': 123, None: 40, 'above': 27})
# Counter({'around': 311, 'below': 114, None: 46, 'above': 30})
# Counter({'around': 294, 'below': 129, None: 45, 'above': 33})
# Counter({'around': 307, 'below': 117, None: 42, 'above': 35})
# Counter({'around': 327, 'below': 104, 'above': 40, None: 30})
# Counter({'around': 318, 'below': 120, None: 35, 'above': 28})
# Counter({'around': 315, 'below': 115, None: 39, 'above': 32})
# Counter({'around': 305, 'below': 122, None: 44, 'above': 30})
# Counter({'around': 320, 'below': 102, None: 43, 'above': 36})
# Counter({'around': 299, 'below': 136, None: 44, 'above': 22})
# Counter({'around': 289, 'below': 141, None: 38, 'above': 33})
# Counter({'around': 298, 'below': 131, None: 43, 'above': 29})
# Counter({'around': 321, 'below': 115, None: 34, 'above': 31})
# Counter({'around': 314, 'below': 124, None: 33, 'above': 30})
# Counter({'around': 292, 'below': 145, None: 35, 'above': 29})
# Counter({'around': 314, 'below': 118, None: 46, 'above': 23})
# Counter({'around': 300, 'below': 133, 'above': 34, None: 34})
# Counter({'around': 313, 'below': 124, None: 38, 'above': 26})
# Counter({'around': 301, 'below': 120, None: 54, 'above': 26})
# Counter({'around': 310, 'below': 118, None: 39, 'above': 34})
# Counter({'around': 315, 'below': 109, None: 51, 'above': 26})
# Counter({'around': 289, 'below': 132, None: 49, 'above': 31})
# Counter({'around': 293, 'below': 129, None: 47, 'above': 32})
# Counter({'around': 324, 'below': 116, None: 37, 'above': 24})
# Counter({'around': 328, 'below': 118, None: 33, 'above': 22})
# Counter({'around': 312, 'below': 112, None: 42, 'above': 35})
# Counter({'around': 307, 'below': 120, 'above': 40, None: 34})
# Counter({'around': 320, 'below': 113, None: 38, 'above': 30})
# Counter({'around': 320, 'below': 109, None: 47, 'above': 25})
# Counter({'around': 304, 'below': 127, None: 41, 'above': 29})
# Counter({'around': 313, 'below': 128, None: 39, 'above': 21})
# Counter({'around': 316, 'below': 117, None: 38, 'above': 30})
# Counter({'around': 311, 'below': 118, None: 42, 'above': 30})
# Counter({'around': 316, 'below': 115, None: 40, 'above': 30})
# Counter({'around': 307, 'below': 117, None: 45, 'above': 32})
# Counter({'around': 305, 'below': 128, None: 42, 'above': 26})
# Counter({'around': 320, 'below': 123, None: 35, 'above': 23})
# Counter({'around': 318, 'below': 116, None: 39, 'above': 28})
# Counter({'around': 307, 'below': 120, None: 49, 'above': 25})
# Counter({'around': 305, 'below': 115, None: 44, 'above': 37})
# Counter({'around': 320, 'below': 118, None: 32, 'above': 31})
# Counter({'around': 308, 'below': 115, None: 48, 'above': 30})
# Counter({'around': 337, 'below': 101, None: 43, 'above': 20})
# Counter({'around': 325, 'below': 118, None: 38, 'above': 20})
# Counter({'around': 341, 'below': 111, None: 36, 'above': 13})
# Counter({'around': 309, 'below': 117, None: 39, 'above': 36})
# Counter({'around': 311, 'below': 128, None: 40, 'above': 22})
# Counter({'around': 306, 'below': 128, 'above': 34, None: 33})
# Counter({'around': 320, 'below': 105, 'above': 38, None: 38})
# Counter({'around': 332, 'below': 103, None: 36, 'above': 30})
# Counter({'around': 313, 'below': 123, None: 35, 'above': 30})
# Counter({'around': 341, 'below': 110, None: 29, 'above': 21})
# Counter({'around': 324, 'below': 115, None: 41, 'above': 21})
# Counter({'around': 323, 'below': 118, None: 33, 'above': 27})
# Counter({'around': 317, 'below': 110, None: 45, 'above': 29})
# Counter({'around': 309, 'below': 123, None: 35, 'above': 34})
# Counter({'around': 314, 'below': 115, 'above': 37, None: 35})
# Counter({'around': 303, 'below': 127, None: 44, 'above': 27})
# Counter({'around': 323, 'below': 118, None: 31, 'above': 29})
# Counter({'around': 297, 'below': 136, 'above': 37, None: 31})
# Counter({'around': 321, 'below': 117, None: 33, 'above': 30})
# Counter({'around': 304, 'below': 122, None: 47, 'above': 28})
# Counter({'around': 322, 'below': 126, None: 29, 'above': 24})
# Counter({'around': 310, 'below': 120, None: 38, 'above': 33})
# Counter({'around': 317, 'below': 110, None: 47, 'above': 27})
# Counter({'around': 307, 'below': 122, None: 40, 'above': 32})
# Counter({'around': 314, 'below': 117, None: 39, 'above': 31})
# Counter({'around': 320, 'below': 122, None: 32, 'above': 27})
# Counter({'around': 310, 'below': 119, None: 38, 'above': 34})
# Counter({'around': 288, 'below': 143, None: 43, 'above': 27})
# Counter({'around': 312, 'below': 111, None: 48, 'above': 30})
# Counter({'around': 321, 'below': 115, None: 33, 'above': 32})
# Counter({'around': 336, 'below': 103, None: 35, 'above': 27})
# Counter({'around': 312, 'below': 134, None: 34, 'above': 21})
# Counter({'around': 304, 'below': 132, None: 34, 'above': 31})
# Counter({'around': 327, 'below': 112, None: 35, 'above': 27})
# Counter({'around': 306, 'below': 129, None: 38, 'above': 28})
# Counter({'around': 313, 'below': 125, None: 36, 'above': 27})
# Counter({'around': 323, 'below': 113, None: 36, 'above': 29})
# Counter({'around': 303, 'below': 115, None: 44, 'above': 39})
# Counter({'around': 334, 'below': 99, None: 39, 'above': 29})
# Counter({'around': 318, 'below': 131, None: 28, 'above': 24})
# Counter({'around': 294, 'below': 132, None: 42, 'above': 33})
# Counter({'around': 321, 'below': 109, 'above': 37, None: 34})
# Counter({'around': 313, 'below': 127, None: 32, 'above': 29})
# Counter({'around': 325, 'below': 105, None: 40, 'above': 31})
# Counter({'around': 317, 'below': 115, None: 41, 'above': 28})
# Counter({'around': 318, 'below': 107, None: 41, 'above': 35})
# Counter({'around': 325, 'below': 116, None: 34, 'above': 26})
# Counter({'around': 319, 'below': 116, None: 35, 'above': 31})
# Counter({'around': 312, 'below': 128, None: 37, 'above': 24})
# Counter({'around': 309, 'below': 133, None: 39, 'above': 20})
# Counter({'around': 298, 'below': 141, None: 39, 'above': 23})
# Counter({'around': 316, 'below': 127, 'above': 33, None: 25})
# Counter({'around': 306, 'below': 127, None: 41, 'above': 27})
# Counter({'around': 305, 'below': 124, None: 45, 'above': 27})
# Counter({'around': 308, 'below': 133, None: 34, 'above': 26})
# Counter({'around': 301, 'below': 128, None: 48, 'above': 24})
# Counter({'around': 308, 'below': 123, None: 36, 'above': 34})
# Counter({'around': 335, 'below': 100, 'above': 34, None: 32})
# Counter({'around': 317, 'below': 103, None: 49, 'above': 32})
# Counter({'around': 300, 'below': 129, None: 38, 'above': 34})
# Counter({'around': 302, 'below': 141, None: 32, 'above': 26})
# Counter({'around': 331, 'below': 96, None: 49, 'above': 25})
# Counter({'around': 325, 'below': 106, None: 38, 'above': 32})
# Counter({'around': 319, 'below': 111, 'above': 38, None: 33})
# Counter({'around': 307, 'below': 127, None: 39, 'above': 28})
# Counter({'around': 317, 'below': 122, None: 34, 'above': 28})
# Counter({'around': 311, 'below': 120, 'above': 36, None: 34})
# Counter({'around': 323, 'below': 110, None: 34, 'above': 34})
# Counter({'around': 314, 'below': 117, None: 39, 'above': 31})
# Counter({'around': 315, 'below': 124, None: 31, 'above': 31})
# Counter({'around': 318, 'below': 119, None: 40, 'above': 24})
# Counter({'around': 321, 'below': 114, None: 44, 'above': 22})
# Counter({'around': 305, 'below': 140, None: 36, 'above': 20})
# Counter({'around': 337, 'below': 104, 'above': 30, None: 30})
# Counter({'around': 314, 'below': 118, None: 37, 'above': 32})
# Counter({'around': 315, 'below': 116, None: 36, 'above': 34})
# Counter({'around': 318, 'below': 117, None: 40, 'above': 26})
# Counter({'around': 292, 'below': 137, None: 39, 'above': 33})
# Counter({'around': 308, 'below': 112, None: 44, 'above': 37})
# Counter({'around': 319, 'below': 105, None: 46, 'above': 31})
# Counter({'around': 302, 'below': 120, None: 48, 'above': 31})
# Counter({'around': 336, 'below': 102, None: 42, 'above': 21})
# Counter({'around': 297, 'below': 127, None: 39, 'above': 38})
# Counter({'around': 330, 'below': 118, 'above': 29, None: 24})
# Counter({'around': 300, 'below': 116, 'above': 45, None: 40})
# Counter({'around': 333, 'below': 106, None: 42, 'above': 20})
# Counter({'around': 313, 'below': 118, None: 42, 'above': 28})
# Counter({'around': 304, 'below': 132, None: 33, 'above': 32})
# Counter({'around': 303, 'below': 126, None: 42, 'above': 30})
# Counter({'around': 322, 'below': 103, None: 48, 'above': 28})
# Counter({'around': 312, 'below': 119, None: 44, 'above': 26})
# Counter({'around': 323, 'below': 110, None: 44, 'above': 24})
# Counter({'around': 316, 'below': 106, None: 51, 'above': 28})
# Counter({'around': 310, 'below': 127, None: 34, 'above': 30})
# Counter({'around': 286, 'below': 129, None: 51, 'above': 35})
# Counter({'around': 315, 'below': 119, 'above': 36, None: 31})
# Counter({'around': 306, 'below': 123, None: 37, 'above': 35})
# Counter({'around': 325, 'below': 116, 'above': 32, None: 28})
# Counter({'around': 319, 'below': 117, None: 38, 'above': 27})
# Counter({'around': 323, 'below': 115, None: 34, 'above': 29})
# Counter({'around': 306, 'below': 124, None: 38, 'above': 33})
# Counter({'around': 323, 'below': 116, None: 35, 'above': 27})
# Counter({'around': 305, 'below': 131, None: 37, 'above': 28})
# Counter({'around': 322, 'below': 104, None: 40, 'above': 35})
# Counter({'around': 301, 'below': 147, None: 36, 'above': 17})
# Counter({'around': 320, 'below': 116, 'above': 34, None: 31})
# Counter({'around': 321, 'below': 115, None: 39, 'above': 26})
# Counter({'around': 305, 'below': 128, None: 43, 'above': 25})
# Counter({'around': 329, 'below': 98, None: 45, 'above': 29})
# Counter({'around': 319, 'below': 103, None: 42, 'above': 37})
# Counter({'around': 316, 'below': 113, None: 44, 'above': 28})
# Counter({'around': 311, 'below': 128, None: 40, 'above': 22})
# Counter({'around': 319, 'below': 116, None: 42, 'above': 24})
# Counter({'around': 322, 'below': 112, None: 38, 'above': 29})
# Counter({'around': 320, 'below': 111, None: 36, 'above': 34})
# Counter({'around': 303, 'below': 118, None: 48, 'above': 32})
# Counter({'around': 318, 'below': 116, 'above': 34, None: 33})
# Counter({'around': 308, 'below': 115, None: 40, 'above': 38})
# Counter({'around': 315, 'below': 107, None: 42, 'above': 37})
# Counter({'around': 330, 'below': 104, None: 36, 'above': 31})
# Counter({'around': 318, 'below': 120, None: 39, 'above': 24})
# Counter({'around': 313, 'below': 115, None: 42, 'above': 31})
# Counter({'around': 324, 'below': 104, None: 40, 'above': 33})
# Counter({'around': 291, 'below': 137, None: 43, 'above': 30})
# Counter({'around': 323, 'below': 101, None: 43, 'above': 34})
# Counter({'around': 322, 'below': 122, 'above': 34, None: 23})
# Counter({'around': 317, 'below': 121, None: 40, 'above': 23})
# Counter({'around': 309, 'below': 119, None: 43, 'above': 30})
# Counter({'around': 313, 'below': 125, None: 34, 'above': 29})
# Counter({'around': 321, 'below': 102, None: 48, 'above': 30})
# Counter({'around': 294, 'below': 143, None: 38, 'above': 26})
# Counter({'around': 323, 'below': 119, None: 34, 'above': 25})
# Counter({'around': 322, 'below': 112, None: 38, 'above': 29})
# Counter({'around': 316, 'below': 112, None: 39, 'above': 34})
# Counter({'around': 324, 'below': 110, None: 39, 'above': 28})
# Counter({'around': 328, 'below': 101, None: 43, 'above': 29})
# Counter({'around': 312, 'below': 118, None: 45, 'above': 26})
# Counter({'around': 316, 'below': 108, None: 43, 'above': 34})
# Counter({'around': 308, 'below': 123, None: 36, 'above': 34})
# Counter({'around': 326, 'below': 100, None: 41, 'above': 34})
# Counter({'around': 328, 'below': 104, None: 39, 'above': 30})
# Counter({'around': 306, 'below': 131, 'above': 32, None: 32})
# Counter({'around': 312, 'below': 125, None: 34, 'above': 30})
# Counter({'around': 298, 'below': 127, None: 42, 'above': 34})
# Counter({'around': 300, 'below': 122, None: 49, 'above': 30})
# Counter({'around': 301, 'below': 141, None: 36, 'above': 23})
# Counter({'around': 319, 'below': 115, None: 35, 'above': 32})
# Counter({'around': 296, 'below': 139, None: 36, 'above': 30})
# Counter({'around': 309, 'below': 117, None: 44, 'above': 31})
# Counter({'around': 321, 'below': 113, None: 41, 'above': 26})
# Counter({'around': 272, 'below': 153, None: 45, 'above': 31})
# Counter({'around': 318, 'below': 110, None: 41, 'above': 32})
# Counter({'around': 317, 'below': 123, None: 33, 'above': 28})
# Counter({'around': 322, 'below': 105, None: 44, 'above': 30})
# Counter({'around': 309, 'below': 127, None: 34, 'above': 31})
# Counter({'around': 325, 'below': 116, None: 33, 'above': 27})
# Counter({'around': 302, 'below': 119, None: 54, 'above': 26})
# Counter({'around': 313, 'below': 118, None: 45, 'above': 25})
# Counter({'around': 315, 'below': 119, None: 39, 'above': 28})
# Counter({'around': 316, 'below': 114, None: 45, 'above': 26})
# Counter({'around': 311, 'below': 112, None: 43, 'above': 35})
# Counter({'around': 298, 'below': 127, 'above': 38, None: 38})
# Counter({'around': 299, 'below': 120, None: 54, 'above': 28})
# Counter({'around': 329, 'below': 105, 'above': 38, None: 29})
# Counter({'around': 320, 'below': 119, 'above': 32, None: 30})
# Counter({'around': 313, 'below': 127, None: 33, 'above': 28})
# Counter({'around': 317, 'below': 123, None: 31, 'above': 30})
# Counter({'around': 308, 'below': 122, None: 41, 'above': 30})
# Counter({'around': 326, 'below': 116, 'above': 30, None: 29})
# Counter({'around': 322, 'below': 106, None: 46, 'above': 27})
# Counter({'around': 335, 'below': 108, None: 35, 'above': 23})
# Counter({'around': 298, 'below': 127, None: 44, 'above': 32})
# Counter({'around': 324, 'below': 119, None: 38, 'above': 20})
# Counter({'around': 313, 'below': 118, None: 37, 'above': 33})
# Counter({'around': 323, 'below': 108, None: 43, 'above': 27})
# Counter({'around': 298, 'below': 126, None: 46, 'above': 31})
# Counter({'around': 310, 'below': 124, None: 38, 'above': 29})
# Counter({'around': 303, 'below': 119, None: 44, 'above': 35})
# Counter({'around': 324, 'below': 116, None: 37, 'above': 24})
# Counter({'around': 323, 'below': 106, None: 42, 'above': 30})
# Counter({'around': 314, 'below': 120, None: 37, 'above': 30})
# Counter({'around': 324, 'below': 102, None: 46, 'above': 29})
# Counter({'around': 327, 'below': 109, None: 33, 'above': 32})
# Counter({'around': 305, 'below': 120, None: 50, 'above': 26})
# Counter({'around': 321, 'below': 103, None: 60, 'above': 17})
# Counter({'around': 332, 'below': 110, None: 34, 'above': 25})
# Counter({'around': 312, 'below': 118, None: 42, 'above': 29})
# Counter({'around': 315, 'below': 116, None: 41, 'above': 29})
# Counter({'around': 317, 'below': 116, None: 40, 'above': 28})
# Counter({'around': 325, 'below': 115, 'above': 31, None: 30})
# Counter({'around': 306, 'below': 133, None: 33, 'above': 29})
# Counter({'around': 316, 'below': 120, None: 37, 'above': 28})
# Counter({'around': 297, 'below': 132, None: 40, 'above': 32})
# Counter({'around': 320, 'below': 103, None: 41, 'above': 37})
# Counter({'around': 297, 'below': 128, None: 45, 'above': 31})
# Counter({'around': 311, 'below': 129, None: 35, 'above': 26})
# Counter({'around': 316, 'below': 114, None: 42, 'above': 29})
# Counter({'around': 330, 'below': 105, 'above': 34, None: 32})
# Counter({'around': 340, 'below': 114, None: 24, 'above': 23})
# Counter({'around': 319, 'below': 119, None: 38, 'above': 25})
# Counter({'around': 298, 'below': 130, None: 44, 'above': 29})
# Counter({'around': 301, 'below': 129, 'above': 36, None: 35})
# Counter({'around': 321, 'below': 106, None: 48, 'above': 26})
# Counter({'around': 325, 'below': 115, None: 33, 'above': 28})
# Counter({'around': 304, 'below': 118, None: 45, 'above': 34})
# Counter({'around': 328, 'below': 102, None: 41, 'above': 30})
# Counter({'around': 309, 'below': 115, None: 48, 'above': 29})
# Counter({'around': 304, 'below': 120, None: 40, 'above': 37})
# Counter({'around': 318, 'below': 118, None: 38, 'above': 27})
# Counter({'around': 323, 'below': 103, None: 49, 'above': 26})
# Counter({'around': 311, 'below': 119, None: 40, 'above': 31})
# Counter({'around': 322, 'below': 126, None: 31, 'above': 22})
# Counter({'around': 298, 'below': 137, None: 41, 'above': 25})
# Counter({'around': 328, 'below': 116, None: 30, 'above': 27})
# Counter({'around': 289, 'below': 132, None: 48, 'above': 32})
# Counter({'around': 313, 'below': 120, None: 36, 'above': 32})
# Counter({'around': 295, 'below': 131, None: 46, 'above': 29})
# Counter({'around': 307, 'below': 113, None: 48, 'above': 33})
# Counter({'around': 326, 'below': 113, None: 33, 'above': 29})
# Counter({'around': 317, 'below': 122, None: 36, 'above': 26})
# Counter({'around': 317, 'below': 125, None: 33, 'above': 26})
# Counter({'around': 309, 'below': 124, None: 39, 'above': 29})
# Counter({'around': 320, 'below': 120, None: 35, 'above': 26})
# Counter({'around': 328, 'below': 110, None: 41, 'above': 22})
# Counter({'around': 310, 'below': 117, None: 40, 'above': 34})
# Counter({'around': 330, 'below': 106, None: 40, 'above': 25})
# Counter({'around': 316, 'below': 114, None: 40, 'above': 31})
# Counter({'around': 340, 'below': 103, None: 42, 'above': 16})
# Counter({'around': 328, 'below': 109, 'above': 32, None: 32})
# Counter({'around': 315, 'below': 113, None: 43, 'above': 30})
# Counter({'around': 316, 'below': 115, 'above': 37, None: 33})
# Counter({'around': 293, 'below': 136, None: 46, 'above': 26})
# Counter({'around': 312, 'below': 122, None: 37, 'above': 30})
# Counter({'around': 299, 'below': 131, None: 38, 'above': 33})
# Counter({'around': 302, 'below': 117, 'above': 41, None: 41})
# Counter({'around': 319, 'below': 108, None: 41, 'above': 33})
# Counter({'around': 322, 'below': 118, None: 41, 'above': 20})
# Counter({'around': 320, 'below': 120, None: 32, 'above': 29})
# Counter({'around': 308, 'below': 124, 'above': 35, None: 34})
# Counter({'around': 318, 'below': 128, None: 34, 'above': 21})
# Counter({'around': 310, 'below': 118, 'above': 39, None: 34})
# Counter({'around': 316, 'below': 121, None: 34, 'above': 30})
# Counter({'around': 326, 'below': 94, None: 45, 'above': 36})
# Counter({'around': 318, 'below': 109, None: 40, 'above': 34})
# Counter({'around': 313, 'below': 125, None: 39, 'above': 24})
# Counter({'around': 323, 'below': 105, None: 41, 'above': 32})
# Counter({'around': 317, 'below': 119, None: 37, 'above': 28})
# Counter({'around': 315, 'below': 129, None: 39, 'above': 18})
# Counter({'around': 306, 'below': 121, None: 45, 'above': 29})
# Counter({'around': 313, 'below': 120, None: 40, 'above': 28})
# Counter({'around': 326, 'below': 105, None: 46, 'above': 24})
# Counter({'around': 313, 'below': 120, None: 40, 'above': 28})
# Counter({'around': 332, 'below': 105, None: 35, 'above': 29})
# Counter({'around': 309, 'below': 126, 'above': 34, None: 32})
# Counter({'around': 320, 'below': 111, None: 40, 'above': 30})
# Counter({'around': 304, 'below': 128, None: 44, 'above': 25})
# Counter({'around': 312, 'below': 109, None: 44, 'above': 36})
# Counter({'around': 319, 'below': 114, None: 40, 'above': 28})
# Counter({'around': 332, 'below': 109, None: 35, 'above': 25})
# Counter({'around': 316, 'below': 115, None: 45, 'above': 25})
# Counter({'around': 313, 'below': 103, None: 49, 'above': 36})
# Counter({'around': 321, 'below': 115, None: 35, 'above': 30})
# Counter({'around': 313, 'below': 126, None: 32, 'above': 30})
# Counter({'around': 318, 'below': 118, None: 43, 'above': 22})
# Counter({'around': 310, 'below': 119, None: 39, 'above': 33})
# Counter({'around': 301, 'below': 124, None: 41, 'above': 35})
# Counter({'around': 347, 'below': 93, None: 42, 'above': 19})
# Counter({'around': 329, 'below': 100, 'above': 39, None: 33})
# Counter({'around': 323, 'below': 121, None: 33, 'above': 24})
# Counter({'around': 314, 'below': 110, None: 46, 'above': 31})
# Counter({'around': 307, 'below': 132, None: 34, 'above': 28})
# Counter({'around': 322, 'below': 111, None: 47, 'above': 21})
# Counter({'around': 322, 'below': 111, None: 38, 'above': 30})
# Counter({'around': 311, 'below': 118, None: 42, 'above': 30})
# Counter({'around': 319, 'below': 105, None: 43, 'above': 34})
# Counter({'around': 320, 'below': 113, None: 36, 'above': 32})
# Counter({'around': 313, 'below': 124, None: 37, 'above': 27})
# Counter({'around': 314, 'below': 117, None: 44, 'above': 26})
# Counter({'around': 308, 'below': 109, None: 48, 'above': 36})
# Counter({'around': 306, 'below': 125, None: 44, 'above': 26})
# Counter({'around': 333, 'below': 104, None: 37, 'above': 27})
# Counter({'around': 307, 'below': 122, None: 38, 'above': 34})
# Counter({'around': 319, 'below': 119, None: 32, 'above': 31})
# Counter({'around': 293, 'below': 132, None: 45, 'above': 31})
# Counter({'around': 308, 'below': 125, None: 41, 'above': 27})
# Counter({'around': 314, 'below': 114, None: 45, 'above': 28})
# Counter({'around': 331, 'below': 106, 'above': 33, None: 31})
# Counter({'around': 315, 'below': 115, None: 47, 'above': 24})
# Counter({'around': 296, 'below': 132, None: 42, 'above': 31})
# Counter({'around': 322, 'below': 97, None: 45, 'above': 37})
# Counter({'around': 298, 'below': 126, None: 42, 'above': 35})
# Counter({'around': 326, 'below': 103, None: 51, 'above': 21})
# Counter({'around': 298, 'below': 131, None: 46, 'above': 26})
# Counter({'around': 308, 'below': 119, None: 46, 'above': 28})
# Counter({'around': 315, 'below': 111, None: 38, 'above': 37})
# Counter({'around': 316, 'below': 115, 'above': 39, None: 31})
# Counter({'around': 317, 'below': 121, None: 37, 'above': 26})
# Counter({'around': 323, 'below': 108, None: 41, 'above': 29})
# Counter({'around': 323, 'below': 107, None: 37, 'above': 34})
# Counter({'around': 320, 'below': 108, None: 41, 'above': 32})
# Counter({'around': 314, 'below': 113, None: 42, 'above': 32})
# Counter({'around': 343, 'below': 102, None: 35, 'above': 21})
# Counter({'around': 317, 'below': 110, None: 40, 'above': 34})
# Counter({'around': 298, 'below': 123, None: 45, 'above': 35})
# Counter({'around': 307, 'below': 121, 'above': 37, None: 36})
# Counter({'around': 298, 'below': 139, None: 36, 'above': 28})
# Counter({'around': 315, 'below': 112, None: 42, 'above': 32})
# Counter({'around': 316, 'below': 110, None: 41, 'above': 34})
# Counter({'around': 314, 'below': 123, None: 34, 'above': 30})
# Counter({'around': 320, 'below': 113, None: 47, 'above': 21})
# Counter({'around': 303, 'below': 128, None: 40, 'above': 30})
# Counter({'around': 306, 'below': 116, None: 50, 'above': 29})
# Counter({'around': 313, 'below': 120, None: 42, 'above': 26})
# Counter({'around': 304, 'below': 117, None: 48, 'above': 32})
# Counter({'around': 305, 'below': 129, None: 41, 'above': 26})
# Counter({'around': 304, 'below': 139, None: 35, 'above': 23})
# Counter({'around': 312, 'below': 120, None: 37, 'above': 32})
# Counter({'around': 312, 'below': 128, None: 32, 'above': 29})
# Counter({'around': 312, 'below': 126, None: 35, 'above': 28})
# Counter({'around': 317, 'below': 112, None: 39, 'above': 33})
# Counter({'around': 314, 'below': 112, None: 42, 'above': 33})
# Counter({'around': 299, 'below': 125, None: 41, 'above': 36})
# Counter({'around': 310, 'below': 124, None: 36, 'above': 31})
# Counter({'around': 308, 'below': 132, None: 36, 'above': 25})
# Counter({'around': 315, 'below': 110, None: 40, 'above': 36})
# Counter({'around': 302, 'below': 128, None: 43, 'above': 28})
# Counter({'around': 334, 'below': 108, None: 33, 'above': 26})
# Counter({'around': 329, 'below': 111, 'above': 31, None: 30})
# Counter({'around': 329, 'below': 118, None: 34, 'above': 20})
# Counter({'around': 294, 'below': 126, None: 49, 'above': 32})
# Counter({'around': 318, 'below': 122, None: 39, 'above': 22})
# Counter({'around': 319, 'below': 107, None: 42, 'above': 33})
# Counter({'around': 328, 'below': 108, None: 39, 'above': 26})
# Counter({'around': 319, 'below': 111, None: 36, 'above': 35})
# Counter({'around': 325, 'below': 113, None: 40, 'above': 23})
# Counter({'around': 321, 'below': 107, None: 41, 'above': 32})
# Counter({'around': 330, 'below': 118, None: 28, 'above': 25})
# Counter({'around': 326, 'below': 110, None: 34, 'above': 31})
# Counter({'around': 325, 'below': 116, None: 40, 'above': 20})
# Counter({'around': 324, 'below': 108, None: 38, 'above': 31})
# Counter({'around': 317, 'below': 109, None: 40, 'above': 35})
# Counter({'around': 309, 'below': 122, None: 39, 'above': 31})
# Counter({'around': 309, 'below': 118, None: 40, 'above': 34})
# Counter({'around': 317, 'below': 113, None: 49, 'above': 22})
# Counter({'around': 303, 'below': 127, None: 42, 'above': 29})
# ...
# Counter({'around': 299, 'below': 136, None: 37, 'above': 29})
# Counter({'around': 343, 'below': 108, None: 30, 'above': 20})
# Counter({'around': 332, 'below': 120, 'above': 28, None: 21})
# Counter({'around': 344, 'below': 105, None: 28, 'above': 24})
# Counter({'around': 318, 'below': 105, None: 42, 'above': 36})
# Counter({'around': 312, 'below': 113, None: 43, 'above': 33})
# Counter({'around': 333, 'below': 106, None: 35, 'above': 27})
# Counter({'around': 318, 'below': 118, None: 41, 'above': 24})
# Counter({'around': 310, 'below': 126, 'above': 33, None: 32})
# Counter({'around': 312, 'below': 118, None: 43, 'above': 28})
# Counter({'around': 297, 'below': 135, None: 42, 'above': 27})
# Counter({'around': 309, 'below': 130, 'above': 33, None: 29})
# Counter({'around': 341, 'below': 103, None: 31, 'above': 26})
# Counter({'around': 330, 'below': 116, 'above': 28, None: 27})
# Counter({'around': 320, 'below': 123, None: 30, 'above': 28})
# Counter({'around': 312, 'below': 108, None: 43, 'above': 38})
# Counter({'around': 305, 'below': 119, None: 42, 'above': 35})
# Counter({'around': 321, 'below': 116, None: 42, 'above': 22})
# Counter({'around': 304, 'below': 125, 'above': 40, None: 32})
# Counter({'around': 306, 'below': 115, None: 47, 'above': 33})
# Counter({'around': 310, 'below': 115, None: 46, 'above': 30})
# Counter({'around': 310, 'below': 115, None: 49, 'above': 27})
# Counter({'around': 303, 'below': 131, None: 44, 'above': 23})
# Counter({'around': 324, 'below': 116, None: 37, 'above': 24})
# Counter({'around': 307, 'below': 118, None: 43, 'above': 33})
# Counter({'around': 306, 'below': 123, None: 42, 'above': 30})
# Counter({'around': 322, 'below': 115, 'above': 36, None: 28})
# Counter({'around': 314, 'below': 116, None: 42, 'above': 29})
# Counter({'around': 322, 'below': 104, None: 40, 'above': 35})
# Counter({'around': 312, 'below': 126, None: 34, 'above': 29})
# Counter({'around': 322, 'below': 113, None: 41, 'above': 25})
# Counter({'around': 328, 'below': 98, None: 45, 'above': 30})
# Counter({'around': 311, 'below': 116, None: 47, 'above': 27})
# Counter({'around': 315, 'below': 122, None: 35, 'above': 29})
# Counter({'around': 329, 'below': 111, None: 37, 'above': 24})
# Counter({'around': 315, 'below': 105, None: 43, 'above': 38})
# Counter({'around': 318, 'below': 121, None: 33, 'above': 29})
# Counter({'around': 314, 'below': 124, None: 39, 'above': 24})
# Counter({'around': 324, 'below': 113, None: 33, 'above': 31})
# Counter({'around': 324, 'below': 116, None: 35, 'above': 26})
# Counter({'around': 319, 'below': 131, 'above': 31, None: 20})
# Counter({'around': 318, 'below': 112, None: 40, 'above': 31})
# Counter({'around': 309, 'below': 121, None: 41, 'above': 30})
# Counter({'around': 320, 'below': 110, None: 39, 'above': 32})
# Counter({'around': 320, 'below': 122, None: 35, 'above': 24})
# Counter({'around': 309, 'below': 126, None: 36, 'above': 30})
# Counter({'around': 313, 'below': 128, None: 36, 'above': 24})
# Counter({'around': 319, 'below': 120, None: 35, 'above': 27})
# Counter({'around': 313, 'below': 124, None: 37, 'above': 27})
# Counter({'around': 301, 'below': 130, None: 53, 'above': 17})
# Counter({'around': 312, 'below': 124, None: 37, 'above': 28})
# Counter({'around': 290, 'below': 143, None: 44, 'above': 24})
# Counter({'around': 317, 'below': 113, None: 40, 'above': 31})
# Counter({'around': 303, 'below': 129, None: 41, 'above': 28})
# Counter({'around': 323, 'below': 123, None: 28, 'above': 27})
# Counter({'around': 303, 'below': 129, None: 36, 'above': 33})
# Counter({'around': 334, 'below': 103, None: 33, 'above': 31})
# Counter({'around': 318, 'below': 117, None: 37, 'above': 29})
# Counter({'around': 322, 'below': 128, None: 31, 'above': 20})
# Counter({'around': 315, 'below': 121, 'above': 35, None: 30})
# Counter({'around': 328, 'below': 109, None: 36, 'above': 28})
# Counter({'around': 320, 'below': 116, 'above': 36, None: 29})
# Counter({'around': 309, 'below': 124, 'above': 35, None: 33})
# Counter({'around': 309, 'below': 120, 'above': 40, None: 32})
# Counter({'around': 319, 'below': 124, None: 39, 'above': 19})
# Counter({'around': 322, 'below': 115, None: 41, 'above': 23})
# Counter({'around': 335, 'below': 101, None: 33, 'above': 32})
# Counter({'around': 297, 'below': 128, None: 42, 'above': 34})
# Counter({'around': 316, 'below': 113, None: 40, 'above': 32})
# Counter({'around': 311, 'below': 119, None: 36, 'above': 35})
# Counter({'around': 324, 'below': 113, 'above': 32, None: 32})
# Counter({'around': 335, 'below': 101, None: 39, 'above': 26})
# Counter({'around': 321, 'below': 114, 'above': 35, None: 31})
# Counter({'around': 319, 'below': 125, None: 38, 'above': 19})
# Counter({'around': 333, 'below': 102, None: 46, 'above': 20})
# Counter({'around': 309, 'below': 121, 'above': 37, None: 34})
# Counter({'around': 328, 'below': 117, None: 33, 'above': 23})
# Counter({'around': 323, 'below': 111, None: 40, 'above': 27})
# Counter({'around': 306, 'below': 135, None: 36, 'above': 24})
# Counter({'around': 311, 'below': 119, None: 38, 'above': 33})
# Counter({'around': 338, 'below': 100, None: 36, 'above': 27})
# Counter({'around': 321, 'below': 115, None: 35, 'above': 30})
# Counter({'around': 314, 'below': 126, None: 31, 'above': 30})
# Counter({'around': 299, 'below': 127, 'above': 42, None: 33})
# Counter({'around': 319, 'below': 101, None: 47, 'above': 34})
# Counter({'around': 330, 'below': 114, None: 33, 'above': 24})
# Counter({'around': 313, 'below': 119, None: 36, 'above': 33})
# Counter({'around': 308, 'below': 124, None: 40, 'above': 29})
# Counter({'around': 301, 'below': 141, None: 38, 'above': 21})
# Counter({'around': 319, 'below': 113, 'above': 35, None: 34})
# Counter({'around': 304, 'below': 122, None: 47, 'above': 28})
# Counter({'around': 326, 'below': 108, None: 39, 'above': 28})
# Counter({'around': 325, 'below': 111, None: 35, 'above': 30})
# Counter({'around': 333, 'below': 123, None: 31, 'above': 14})
# Counter({'around': 319, 'below': 120, None: 36, 'above': 26})
# Counter({'around': 314, 'below': 112, None: 42, 'above': 33})
# Counter({'around': 329, 'below': 107, None: 43, 'above': 22})
# Counter({'around': 322, 'below': 118, None: 32, 'above': 29})
# Counter({'around': 332, 'below': 105, None: 35, 'above': 29})
# Counter({'around': 336, 'below': 103, 'above': 33, None: 29})
# Counter({'around': 298, 'below': 138, None: 36, 'above': 29})
# Counter({'around': 302, 'below': 125, None: 48, 'above': 26})
# Counter({'around': 312, 'below': 126, None: 42, 'above': 21})
# Counter({'around': 310, 'below': 126, None: 39, 'above': 26})
# Counter({'around': 333, 'below': 98, None: 43, 'above': 27})
# Counter({'around': 312, 'below': 113, None: 46, 'above': 30})
# Counter({'around': 311, 'below': 117, None: 42, 'above': 31})
# Counter({'around': 310, 'below': 115, None: 46, 'above': 30})
# Counter({'around': 294, 'below': 132, 'above': 39, None: 36})
# Counter({'around': 320, 'below': 108, 'above': 38, None: 35})
# Counter({'around': 323, 'below': 110, None: 37, 'above': 31})
# Counter({'around': 324, 'below': 114, None: 41, 'above': 22})
# Counter({'around': 319, 'below': 120, None: 34, 'above': 28})
# Counter({'around': 320, 'below': 121, None: 34, 'above': 26})
# Counter({'around': 313, 'below': 118, 'above': 36, None: 34})
# Counter({'around': 307, 'below': 115, 'above': 42, None: 37})
# Counter({'around': 316, 'below': 117, None: 37, 'above': 31})
# Counter({'around': 318, 'below': 119, None: 41, 'above': 23})
# Counter({'around': 299, 'below': 126, None: 43, 'above': 33})
# Counter({'around': 300, 'below': 127, None: 44, 'above': 30})
# Counter({'around': 317, 'below': 123, None: 34, 'above': 27})
# Counter({'around': 314, 'below': 126, None: 33, 'above': 28})
# Counter({'around': 323, 'below': 109, None: 38, 'above': 31})
# Counter({'around': 306, 'below': 133, None: 35, 'above': 27})
# Counter({'around': 322, 'below': 114, None: 39, 'above': 26})
# Counter({'around': 313, 'below': 112, None: 48, 'above': 28})
# Counter({'around': 321, 'below': 105, None: 40, 'above': 35})
# Counter({'around': 333, 'below': 112, None: 30, 'above': 26})
# Counter({'around': 285, 'below': 147, None: 40, 'above': 29})
# Counter({'around': 313, 'below': 129, None: 34, 'above': 25})
# Counter({'around': 311, 'below': 119, None: 46, 'above': 25})
# Counter({'around': 307, 'below': 120, None: 45, 'above': 29})
# Counter({'around': 299, 'below': 122, None: 46, 'above': 34})
# Counter({'around': 309, 'below': 120, None: 46, 'above': 26})
# Counter({'around': 323, 'below': 106, None: 46, 'above': 26})
# Counter({'around': 316, 'below': 115, None: 40, 'above': 30})
# Counter({'around': 337, 'below': 110, None: 33, 'above': 21})
# Counter({'around': 308, 'below': 114, None: 48, 'above': 31})
# Counter({'around': 311, 'below': 131, 'above': 34, None: 25})
# Counter({'around': 306, 'below': 125, None: 37, 'above': 33})
# Counter({'around': 320, 'below': 112, None: 44, 'above': 25})
# Counter({'around': 308, 'below': 125, None: 35, 'above': 33})
# Counter({'around': 319, 'below': 109, None: 46, 'above': 27})
# Counter({'around': 302, 'below': 127, None: 39, 'above': 33})
# Counter({'around': 311, 'below': 118, None: 47, 'above': 25})
# Counter({'around': 319, 'below': 109, None: 39, 'above': 34})
# Counter({'around': 310, 'below': 122, None: 42, 'above': 27})
# Counter({'around': 306, 'below': 125, None: 41, 'above': 29})
# Counter({'around': 327, 'below': 114, None: 33, 'above': 27})
# Counter({'around': 331, 'below': 119, None: 28, 'above': 23})
# Counter({'around': 315, 'below': 121, None: 41, 'above': 24})
# Counter({'around': 308, 'below': 120, None: 51, 'above': 22})
# Counter({'around': 309, 'below': 120, None: 44, 'above': 28})
# Counter({'around': 320, 'below': 118, None: 38, 'above': 25})
# Counter({'around': 332, 'below': 103, None: 38, 'above': 28})
# Counter({'around': 309, 'below': 120, None: 40, 'above': 32})
# Counter({'around': 333, 'below': 106, None: 33, 'above': 29})
# Counter({'around': 316, 'below': 110, None: 44, 'above': 31})
# Counter({'around': 324, 'below': 106, 'above': 37, None: 34})
# Counter({'around': 329, 'below': 99, 'above': 39, None: 34})
# Counter({'around': 304, 'below': 125, None: 40, 'above': 32})
# Counter({'around': 292, 'below': 121, None: 50, 'above': 38})
# Counter({'around': 330, 'below': 102, None: 45, 'above': 24})
# Counter({'around': 305, 'below': 121, None: 49, 'above': 26})
# Counter({'around': 315, 'below': 115, None: 42, 'above': 29})
# Counter({'around': 315, 'below': 102, None: 45, 'above': 39})
# Counter({'around': 298, 'below': 126, None: 49, 'above': 28})
# Counter({'around': 319, 'below': 121, None: 41, 'above': 20})
# Counter({'around': 299, 'below': 128, 'above': 38, None: 36})
# Counter({'around': 302, 'below': 124, None: 38, 'above': 37})
# Counter({'around': 316, 'below': 106, None: 44, 'above': 35})
# Counter({'around': 318, 'below': 136, None: 25, 'above': 22})
# Counter({'around': 310, 'below': 112, None: 42, 'above': 37})
# Counter({'around': 314, 'below': 118, None: 39, 'above': 30})
# Counter({'around': 342, 'below': 111, None: 28, 'above': 20})
# Counter({'around': 297, 'below': 127, None: 47, 'above': 30})
# Counter({'around': 315, 'below': 116, None: 45, 'above': 25})
# Counter({'around': 318, 'below': 107, None: 43, 'above': 33})
# Counter({'around': 308, 'below': 132, 'above': 32, None: 29})
# Counter({'around': 328, 'below': 100, None: 40, 'above': 33})
# Counter({'around': 320, 'below': 110, None: 44, 'above': 27})
# Counter({'around': 318, 'below': 115, None: 43, 'above': 25})
# Counter({'around': 318, 'below': 110, None: 43, 'above': 30})
# Counter({'around': 310, 'below': 122, None: 35, 'above': 34})
# Counter({'around': 310, 'below': 122, None: 44, 'above': 25})
# Counter({'around': 315, 'below': 115, None: 41, 'above': 30})
# Counter({'around': 301, 'below': 116, None: 48, 'above': 36})
# Counter({'around': 322, 'below': 110, None: 41, 'above': 28})
# Counter({'around': 336, 'below': 106, None: 43, 'above': 16})
# Counter({'around': 320, 'below': 116, None: 36, 'above': 29})
# Counter({'around': 331, 'below': 117, None: 31, 'above': 22})
# Counter({'around': 312, 'below': 108, None: 44, 'above': 37})
# Counter({'around': 330, 'below': 99, None: 42, 'above': 30})
# Counter({'around': 322, 'below': 116, 'above': 35, None: 28})
# Counter({'around': 315, 'below': 109, 'above': 40, None: 37})
# Counter({'around': 300, 'below': 129, None: 37, 'above': 35})
# Counter({'around': 320, 'below': 124, 'above': 29, None: 28})
# Counter({'around': 306, 'below': 120, None: 45, 'above': 30})
# Counter({'around': 314, 'below': 122, None: 35, 'above': 30})
# Counter({'around': 306, 'below': 104, None: 49, 'above': 42})
# Counter({'around': 334, 'below': 98, None: 35, 'above': 34})
# Counter({'around': 315, 'below': 110, None: 45, 'above': 31})
# Counter({'around': 322, 'below': 100, None: 42, 'above': 37})
# Counter({'around': 321, 'below': 109, None: 39, 'above': 32})
# Counter({'around': 329, 'below': 104, None: 37, 'above': 31})
# Counter({'around': 313, 'below': 115, None: 42, 'above': 31})
# Counter({'around': 327, 'below': 111, None: 42, 'above': 21})
# Counter({'around': 321, 'below': 112, None: 39, 'above': 29})
# Counter({'around': 311, 'below': 135, 'above': 30, None: 25})
# Counter({'around': 310, 'below': 124, None: 41, 'above': 26})
# Counter({'around': 318, 'below': 112, None: 43, 'above': 28})
# Counter({'around': 307, 'below': 112, None: 41, 'above': 41})
# Counter({'around': 320, 'below': 114, None: 42, 'above': 25})
# Counter({'around': 340, 'below': 91, None: 46, 'above': 24})
# Counter({'around': 308, 'below': 120, None: 43, 'above': 30})
# Counter({'around': 314, 'below': 123, 'above': 35, None: 29})
# Counter({'around': 315, 'below': 117, None: 39, 'above': 30})
# Counter({'around': 312, 'below': 125, None: 34, 'above': 30})
# Counter({'around': 314, 'below': 121, None: 39, 'above': 27})
# Counter({'around': 299, 'below': 123, None: 49, 'above': 30})
# Counter({'around': 310, 'below': 122, None: 42, 'above': 27})
# Counter({'around': 318, 'below': 107, None: 44, 'above': 32})
# Counter({'around': 303, 'below': 119, 'above': 41, None: 38})
# Counter({'around': 331, 'below': 101, None: 41, 'above': 28})
# Counter({'around': 309, 'below': 122, None: 42, 'above': 28})
# Counter({'around': 312, 'below': 124, None: 35, 'above': 30})
# Counter({'around': 312, 'below': 117, None: 50, 'above': 22})
# Counter({'around': 325, 'below': 121, None: 29, 'above': 26})
# Counter({'around': 324, 'below': 117, 'above': 30, None: 30})
# Counter({'around': 301, 'below': 116, None: 46, 'above': 38})
# Counter({'around': 309, 'below': 133, None: 34, 'above': 25})
# Counter({'around': 337, 'below': 113, None: 32, 'above': 19})
# Counter({'around': 305, 'below': 121, 'above': 38, None: 37})
# Counter({'around': 313, 'below': 106, None: 47, 'above': 35})
# Counter({'around': 324, 'below': 111, None: 42, 'above': 24})
# Counter({'around': 307, 'below': 125, None: 39, 'above': 30})
# Counter({'around': 289, 'below': 125, None: 49, 'above': 38})
# Counter({'around': 307, 'below': 123, None: 36, 'above': 35})
# Counter({'around': 298, 'below': 127, None: 45, 'above': 31})
# Counter({'around': 314, 'below': 118, None: 49, 'above': 20})
# Counter({'around': 308, 'below': 130, None: 36, 'above': 27})
# Counter({'around': 322, 'below': 117, None: 31, 'above': 31})
# Counter({'around': 315, 'below': 120, None: 38, 'above': 28})
# Counter({'around': 332, 'below': 101, None: 39, 'above': 29})
# Counter({'around': 325, 'below': 110, None: 38, 'above': 28})
# Counter({'around': 303, 'below': 122, 'above': 40, None: 36})
# Counter({'around': 317, 'below': 109, None: 47, 'above': 28})
# Counter({'around': 322, 'below': 116, None: 32, 'above': 31})
# Counter({'around': 315, 'below': 122, None: 39, 'above': 25})
# Counter({'around': 315, 'below': 109, None: 42, 'above': 35})
# Counter({'around': 312, 'below': 115, None: 45, 'above': 29})
# Counter({'around': 322, 'below': 100, None: 43, 'above': 36})
# Counter({'around': 304, 'below': 133, 'above': 38, None: 26})
# Counter({'around': 313, 'below': 111, None: 42, 'above': 35})
# Counter({'around': 309, 'below': 123, None: 41, 'above': 28})
# Counter({'around': 308, 'below': 125, None: 37, 'above': 31})
# Counter({'around': 316, 'below': 129, 'above': 30, None: 26})
# Counter({'around': 308, 'below': 125, 'above': 36, None: 32})

# %%
def plot_multiscale_neutrality_mutation_kind_normalized_by_layer(file, layer):
    with open(file, 'rb') as pf:
        hc = pickle.load(pf)

    all_above = []
    all_around = []
    all_below = []

    above_neutral = []
    around_neutral = []
    below_neutral = []
    
    for gen in range(0, len(hc.mutation_data_over_generations)-1):
        neutral = [pair[0] == pair[1] for pair in hc.parent_child_fitness_history[gen+1]]
        n_neutral = sum(neutral)

        layer_kind_pairs = list(zip(hc.mutation_data_over_generations[gen]['kind'], hc.mutation_data_over_generations[gen]['layer']))
        layer_kind = Counter(layer_kind_pairs)
    
        n_layer_mutations = layer_kind[('above', layer)] + layer_kind[('around', layer)] + layer_kind[('below', layer)]
        all_above.append(layer_kind[('above', layer)] / n_layer_mutations)
        all_around.append(layer_kind[('around', layer)] / n_layer_mutations)
        all_below.append(layer_kind[('below', layer)] / n_layer_mutations)

        neutral_layer_kind = Counter([pair for i, pair in enumerate(layer_kind_pairs) if neutral[i] and pair[1] == layer])
        n_layer_neutral_mutations = sum(neutral_layer_kind.values())
        if n_layer_neutral_mutations == 0:
            above_neutral.append(0)
            around_neutral.append(0)
            below_neutral.append(0)
            continue

        above_neutral.append(neutral_layer_kind[('above', layer)] / n_layer_neutral_mutations)
        around_neutral.append(neutral_layer_kind[('around', layer)] / n_layer_neutral_mutations)
        below_neutral.append(neutral_layer_kind[('below', layer)] / n_layer_neutral_mutations)



        # neutral_count = Counter(kind_neutral)

    gen_avg = 30
    # print(above_neutral)
    time_avg_all_above = compress_array(all_above, gen_avg)
    time_avg_all_around = compress_array(all_around, gen_avg)
    time_avg_all_below = compress_array(all_below, gen_avg)

    time_avg_above = compress_array(above_neutral, gen_avg)
    time_avg_around = compress_array(around_neutral, gen_avg)
    time_avg_below = compress_array(below_neutral, gen_avg)

    x_vals = range(0, len(hc.mutation_data_over_generations)-1, gen_avg)

    plt.plot(x_vals, time_avg_all_above, label='Above neutral (all)')
    plt.plot(x_vals, time_avg_all_around, label='Around neutral (all)')
    plt.plot(x_vals, time_avg_all_below, label='Below neutral (all)')

    plt.plot(x_vals, time_avg_above, label='Above neutral')
    plt.plot(x_vals, time_avg_around, label='Around neutral')
    plt.plot(x_vals, time_avg_below, label='Below neutral')

    plt.legend()

    plt.xlabel('Generation')
    plt.ylabel('Neutral mutations as a proportion of all mutations')
    plt.title('Neutral mutations as a proportion of all mutations at each layer')
        

plot_multiscale_neutrality_mutation_kind_normalized_by_layer('./hillclimber_test_t0.pkl', layer=3)

# %%
plot_normalized_multiscale_neutrality('./hc_testeroni_4000.pkl')
