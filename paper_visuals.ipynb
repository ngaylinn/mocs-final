# %%
from analysis import plot_average_fitness, strip_plot, plot_fitness_proportion

# %% [markdown]
# # Circle, base 1, 1-4 layers

# %%
directories = [
    './experiments_paper/exp_circle_1layer/base1_64',
    './experiments_paper/exp_circle_2layer/base1_64.32',
    './experiments_paper/exp_circle_3layer/base1_circle_64.32.16',
    './experiments_paper/exp_circle_4layer/base1_circle_64.32.16.8',
]

labels = [
    '1 layer',
    '2 layers',
    '3 layers',
    '4 layers',
]

plot_average_fitness(directories, labels)
strip_plot(directories, labels)

# %% [markdown]
# # Square, base 1, 1-4 layers

# %%
directories = [
    './experiments_paper/exp_square_1layer/base1_64',
    './experiments_paper/exp_square_2layer/base1_64.32',
    './experiments_paper/exp_square_3layer/base1_64.32.16',
    './experiments_paper/exp_square_4layer/base1_64.32.16.8',
]

labels = [
    '1 layer',
    '2 layers',
    '3 layers',
    '4 layers',
]

plot_average_fitness(directories, labels)
strip_plot(directories, labels)

# %% [markdown]
# # Diamond, base 1, 1-4 layers

# %%
directories = [
    './experiments_paper/exp_diamond_1layer/base1_64',
    './experiments_paper/exp_diamond_2layer/base1_64.32',
    './experiments_paper/exp_diamond_3layer/base1_64.32.16',
    './experiments_paper/exp_diamond_4layer/base1_diamond_64.32.16.8',
]

labels = [
    '1 layer',
    '2 layers',
    '3 layers',
    '4 layers',
]

plot_average_fitness(directories, labels)
strip_plot(directories, labels)

# %% [markdown]
# # Controls comparison, square, 1-4 layers

# %%
directories = [
    './experiments_paper/exp_square_2layer/base1_64.32',
    './experiments_paper/exp_square_control_2layer/base1_64.32',
]

labels = [
    'Hierarchical Structure',
    'Control',
]

plot_average_fitness(directories, labels)
strip_plot(directories, labels)

# %%
directories = [
    './experiments_paper/exp_square_3layer/base1_64.32.16',
    './experiments_paper/exp_square_control_3layer/base1_64.32',
]

labels = [
    'Hierarchical Structure',
    'Control',
]

plot_average_fitness(directories, labels)
strip_plot(directories, labels)

# %%
directories = [
    './experiments_paper/exp_square_4layer/base1_64.32.16.8',
    './experiments_paper/exp_square_control_4layer/base1_64.32',
]

labels = [
    'Hierarchical Structure',
    'Control',
]

plot_average_fitness(directories, labels)
strip_plot(directories, labels)

# %% [markdown]
# # Controls comparison, circle, 1-4 layers

# %%
directories = [
    './experiments_paper/exp_circle_2layer/base1_64.32',
    './experiments_paper/exp_circle_control_2layer/base1_64.32',
]

labels = [
    'Hierarchical Structure',
    'Control',
]

plot_average_fitness(directories, labels)
strip_plot(directories, labels)

# %%
directories = [
    './experiments_paper/exp_circle_3layer/base1_circle_64.32.16',
    './experiments_paper/exp_circle_control_3layer/base1_64.32',
]

labels = [
    'Hierarchical Structure',
    'Control',
]

plot_average_fitness(directories, labels)
strip_plot(directories, labels)

# %%
directories = [
    './experiments_paper/exp_circle_4layer/base1_circle_64.32.16.8',
    './experiments_paper/exp_circle_control_4layer/base1_64.32',
]

labels = [
    'Hierarchical Structure',
    'Control',
]

plot_average_fitness(directories, labels)
strip_plot(directories, labels)

# %% [markdown]
# # Controls layers 2-4, diamond

# %%
directories = [
    './experiments_paper/exp_diamond_2layer/base1_64.32',
    './experiments_paper/exp_diamond_control_2layer/base1_64.32',
]

labels = [
    'Hierarchical Structure',
    'Control',
]

plot_average_fitness(directories, labels)
strip_plot(directories, labels)

# %%
directories = [
    './experiments_paper/exp_diamond_3layer/base1_64.32.16',
    './experiments_paper/exp_diamond_control_3layer/base1_64.32',
]

labels = [
    'Hierarchical Structure',
    'Control',
]

plot_average_fitness(directories, labels)
strip_plot(directories, labels)

# %%
directories = [
    './experiments_paper/exp_diamond_4layer/base1_diamond_64.32.16.8',
    './experiments_paper/exp_diamond_control_4layer/base1_64.32',
]

labels = [
    'Hierarchical Structure',
    'Control',
]

plot_average_fitness(directories, labels)
strip_plot(directories, labels)

# %% [markdown]
# # Control Comparisons, square

# %%
directories = [
    './experiments_paper/exp_circle_1layer/base1_64',
    './experiments_paper/exp_circle_control_2layer/base1_64.32',
    './experiments_paper/exp_circle_control_3layer/base1_64.32',
    './experiments_paper/exp_circle_control_4layer/base1_64.32',
]

labels = [
    'Control: 1 layer',
    'Control: 2 layer',
    'Control: 3 layer',
    'Control: 4 layer',
]

plot_average_fitness(directories, labels)
strip_plot(directories, labels)

# %% [markdown]
# # Control comparisons, square

# %%
directories = [
    './experiments_paper/exp_square_1layer/base1_64',
    './experiments_paper/exp_square_control_2layer/base1_64.32',
    './experiments_paper/exp_square_control_3layer/base1_64.32',
    './experiments_paper/exp_square_control_4layer/base1_64.32',
]

labels = [
    'Control: 1 layer',
    'Control: 2 layer',
    'Control: 3 layer',
    'Control: 4 layer',
]

plot_average_fitness(directories, labels)
strip_plot(directories, labels)

# %% [markdown]
# # Controls comparison, diamond

# %%
directories = [
    './experiments_paper/exp_diamond_1layer/base1_64',
    './experiments_paper/exp_diamond_control_2layer/base1_64.32',
    './experiments_paper/exp_diamond_control_3layer/base1_64.32',
    './experiments_paper/exp_diamond_control_4layer/base1_64.32',
]

labels = [
    'Control: 1 layer',
    'Control: 2 layer',
    'Control: 3 layer',
    'Control: 4 layer',
]

plot_average_fitness(directories, labels)
strip_plot(directories, labels)

# %% [markdown]
# # Selection at different levels of resolution

# %% [markdown]
# ## Diamond selection @ various levels of resolution

# %%
directories = [
    './experiments_paper/exp_diamond_4layer/base4_diamond_64.32.16.8',
    './experiments_paper/exp_diamond_4layer/base3_diamond_64.32.16.8',
    './experiments_paper/exp_diamond_4layer/base2_diamond_64.32.16.8',
    './experiments_paper/exp_diamond_4layer/base1_diamond_64.32.16.8',
]

labels = [
    'Layer 4 selection',
    'Layer 3 selection',
    'Layer 2 selection',
    'Layer 1 selection',
]

colors = [
    'Red',
    'Green',
    'Orange',
    'Blue'
]

plot_average_fitness(directories, labels)
strip_plot(directories, labels)
plot_fitness_proportion(directories, labels, colors)

# %%
directories = [
    './experiments_paper/exp_square_4layer/base4_64.32.16.8',
    './experiments_paper/exp_square_4layer/base3_64.32.16.8',
    './experiments_paper/exp_square_4layer/base2_64.32.16.8',
    './experiments_paper/exp_square_4layer/base1_64.32.16.8',
]

labels = [
    'Layer 4 selection',
    'Layer 3 selection',
    'Layer 2 selection',
    'Layer 1 selection',
]

colors = [
    'Red',
    'Green',
    'Orange',
    'Blue'
]

plot_average_fitness(directories, labels)
strip_plot(directories, labels)
plot_fitness_proportion(directories, labels, colors)

# %%
directories = [
    './experiments_paper/exp_circle_4layer/base4_circle_64.32.16.8',
    './experiments_paper/exp_circle_4layer/base3_circle_64.32.16.8',
    './experiments_paper/exp_circle_4layer/base2_circle_64.32.16.8',
    './experiments_paper/exp_circle_4layer/base1_circle_64.32.16.8',
]

labels = [
    'Layer 4 selection',
    'Layer 3 selection',
    'Layer 2 selection',
    'Layer 1 selection',
]

colors = [
    'Red',
    'Green',
    'Orange',
    'Blue'
]

plot_average_fitness(directories, labels)
strip_plot(directories, labels)
plot_fitness_proportion(directories, labels, colors)

# %%
directories = [
    './experiments_paper/exp_square_control_2layer/base1_64.32',
    './exp_square_2layer/base1_64.32',
]

labels = [
    'Control',
    'hierarchical',
]

plot_average_fitness(directories, labels)
strip_plot(directories, labels)

# %%
directories = [
    './experiments_redo/exp_diamond_4layer/base1_64.32.16',
    './experiments_paper/exp_diamond_4layer/base1_diamond_64.32.16.8',
]

labels = [
    'AFPO',
    'Random',
]

plot_average_fitness(directories, labels)
strip_plot(directories, labels)

# %%
directories = [
    './experiments_redo/exp_diamond_4layer/base2_64.32.16',
    './experiments_paper/exp_diamond_4layer/base2_diamond_64.32.16.8',
]

labels = [
    'AFPO',
    'Random',
]

plot_average_fitness(directories, labels)
strip_plot(directories, labels)

# %%
directories = [
    './experiments_redo/exp_diamond_4layer/base3_64.32.16',
    './experiments_paper/exp_diamond_4layer/base3_diamond_64.32.16.8',
]

labels = [
    'AFPO',
    'Random',
]

plot_average_fitness(directories, labels)
strip_plot(directories, labels)

# %%
directories = [
    './experiments_redo/exp_diamond_4layer/base4_64.32.16',
    './experiments_paper/exp_diamond_4layer/base4_diamond_64.32.16.8',
]

labels = [
    'AFPO',
    'Random',
]

plot_average_fitness(directories, labels)
strip_plot(directories, labels)

# %%
directories = [
    './experiments_redo/exp_circle_4layer/base1_circle_64.32.16.8',
    './experiments_paper/exp_circle_4layer/base1_circle_64.32.16.8',
]

labels = [
    'AFPO',
    'Random',
]

plot_average_fitness(directories, labels)
strip_plot(directories, labels)

# %%
directories = [
    './experiments_redo/exp_diamond_3layer/base1_64.32.16',
    './experiments_paper/exp_diamond_3layer/base1_64.32.16',
]

labels = [
    'AFPO',
    'Random',
]

plot_average_fitness(directories, labels)
strip_plot(directories, labels)

# %%
directories = [
    './experiments_redo/exp_square_1layer/base1_64',
    './experiments_redo/exp_square_2layer/base1_64.32',
    './experiments_redo/exp_square_3layer/base1_64.32.16',
    './experiments_redo/exp_square_4layer/base1_64.32.16',
]

labels = [
    '1 layer',
    '2 layers',
    '3 layers',
    '4 layers',
]

plot_average_fitness(directories, labels)
strip_plot(directories, labels)

# %%
directories = [
    './experiments_redo/exp_square_4layer/base1_64.32.16',
    './experiments_redo/exp_square_control_4layer/base1',
]

labels = [
    'AFPO_hierarchical',
    'AFPO_control',
]

plot_average_fitness(directories, labels)
strip_plot(directories, labels)

# %%
directories = [
    './experiments_redo/exp_square_3layer/base1_64.32.16',
    './experiments_redo/exp_square_control_3layer/base1',
]

labels = [
    'AFPO_hierarchical',
    'AFPO_control',
]

plot_average_fitness(directories, labels)
strip_plot(directories, labels)

# %%
directories = [
    './experiments_redo/exp_square_2layer/base1_64.32',
    './experiments_redo/exp_square_control_2layer/base1',
]

labels = [
    'AFPO_hierarchical',
    'AFPO_control',
]


plot_average_fitness(directories, labels)
strip_plot(directories, labels)

# %%
directories = [
    './experiments_redo/exp_square_1layer/base1_64',
    './experiments_paper/exp_square_1layer/base1_64',
]

labels = [
    'AFPO',
    'Random',
]


plot_average_fitness(directories, labels)
strip_plot(directories, labels)

# %%
directories = [
    './experiments_redo/exp_square_2layer/base1_64.32',
    './experiments_paper/exp_square_2layer/base1_64.32',
]

labels = [
    'AFPO',
    'Random',
]


plot_average_fitness(directories, labels)
strip_plot(directories, labels)

# %%
directories = [
    './experiments_redo/exp_square_3layer/base1_64.32.16',
    './experiments_paper/exp_square_3layer/base1_64.32.16',
]

labels = [
    'AFPO',
    'Random',
]


plot_average_fitness(directories, labels)
strip_plot(directories, labels)

# %%
directories = [
    './experiments_redo/exp_square_4layer/base1_64.32.16',
    './experiments_paper/exp_square_4layer/base1_64.32.16.8',
]

labels = [
    'AFPO',
    'Random',
]


plot_average_fitness(directories, labels)
strip_plot(directories, labels)

# %%
directories = [
    './experiments_redo/rand_control_prelim/base2_square_randcontrol',
    './experiments_redo/exp_square_4layer/base2_64.32.16',
]

labels = [
    'Control',
    'Hierarchical',
]


plot_average_fitness(directories, labels)
strip_plot(directories, labels)

# %%
directories = [
    './experiments_redo/rand_control_prelim/base3_square_randcontrol',
    './experiments_redo/exp_square_4layer/base3_64.32.16',
]

labels = [
    'Control',
    'Hierarchical',
]


plot_average_fitness(directories, labels)
strip_plot(directories, labels)

# %%
directories = [
    './experiments_redo/rand_control_prelim/base4_square_randcontrol',
    './experiments_redo/exp_square_4layer/base4_64.32.16',
]

labels = [
    'Control',
    'Hierarchical',
]


plot_average_fitness(directories, labels)
strip_plot(directories, labels)

# %%
directories = [
    './experiments_redo/rand_control_prelim/base1_square_randcontrol',
    './experiments_redo/exp_square_4layer/base1_64.32.16',
]

labels = [
    'Control',
    'Hierarchical',
]


plot_average_fitness(directories, labels)
strip_plot(directories, labels)

# %%
directories = [
    './experiments_redo/exp_square_4layer/base1_64.32.16',
    './experiments_redo/random_control_square_final/l4_b1_square_randcontrol',
]

labels = [
    'Hierarchical',
    'Control',
]


plot_average_fitness(directories, labels)
strip_plot(directories, labels)

# %%
directories = [
    './experiments_redo/exp_square_3layer/base1_64.32.16',
    './experiments_redo/random_control_square_final/l3_b1_square_randcontrol',
]

labels = [
    'Hierarchical',
    'Control',
]


plot_average_fitness(directories, labels)
strip_plot(directories, labels)

# %%
directories = [
    './experiments_redo/exp_square_2layer/base1_64.32',
    './experiments_redo/random_control_square_final/l2_b1_square_randcontrol',
]

labels = [
    'Hierarchical',
    'Control',
]


plot_average_fitness(directories, labels)
strip_plot(directories, labels)
