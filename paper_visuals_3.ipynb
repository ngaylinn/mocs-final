# %%
from analysis import plot_average_nonzero_proportion, plot_downward_weights_magnitudes

# %%
folder_name = './experiments_paper/exp_circle_4layer/base1_circle_64.32.16.8_phenotypes'

# plot_average_nonzero_proportion(folder_name, n_layers=4)

# %%
folder_name = './experiments_paper/exp_circle_4layer/base1_circle_64.32.16.8_phenotypes'

plot_downward_weights_magnitudes(folder_name, n_layers=4)
